# %%
import pandas as pd
from sqlalchemy import create_engine, text
import os
from datetime import datetime
import numpy as np

# %%
# Database connection configuration
DB_CONFIG = {
    'host': 'localhost',
    'user': 'root',
    'password': 'Keklol360**',
    'database': 'diggerz'
}

# %%
def create_mysql_engine():
    """Create SQLAlchemy engine for MySQL connection"""
    connection_string = f"mysql+pymysql://{DB_CONFIG['user']}:{DB_CONFIG['password']}@{DB_CONFIG['host']}/{DB_CONFIG['database']}"
    return create_engine(connection_string)

def clean_dataframe(df):
    """Enhanced dataframe cleaning function"""
    # Handle string columns
    for col in df.select_dtypes(include=['object']).columns:
        df[col] = df[col].fillna('Unknown')
        if col in ['release_title', 'label_name', 'artist_name', 'track_title']:
            df[col] = df[col].apply(lambda x: str(x).replace("'", "''"))
    
    # Handle numeric columns
    for col in df.select_dtypes(include=['int64', 'float64']).columns:
        df[col] = df[col].fillna(0)
    
    # Handle datetime columns
    date_columns = ['updated_on', 'release_date']
    for col in date_columns:
        if col in df.columns:
            df[col] = pd.to_datetime(df[col], errors='coerce')
            df[col] = df[col].fillna(pd.Timestamp('2020-01-01'))
    
    return df

def create_database_schema(engine):
    """Create database tables"""
    try:
        print("Creating database schema...")
        with engine.connect() as conn:
            # Create ARTIST table
            conn.execute(text("""
            CREATE TABLE IF NOT EXISTS artist (
                artist_id VARCHAR(255) PRIMARY KEY,
                artist_name VARCHAR(255) NOT NULL,
                updated_on DATETIME NOT NULL
            )
            """))

            # Create RELEASE table
            conn.execute(text("""
            CREATE TABLE IF NOT EXISTS `release` (
                release_id VARCHAR(255) PRIMARY KEY,
                release_title VARCHAR(255) NOT NULL,
                release_date DATE,
                upc VARCHAR(255),
                popularity INT,
                total_tracks INT,
                album_type VARCHAR(50),
                release_img VARCHAR(255),
                label_name VARCHAR(255),
                updated_on DATETIME NOT NULL
            )
            """))

            # Create TRACK table
            conn.execute(text("""
            CREATE TABLE IF NOT EXISTS track (
                track_id VARCHAR(255) PRIMARY KEY,
                track_title VARCHAR(255) NOT NULL,
                duration_ms INT,
                isrc VARCHAR(255) UNIQUE,
                track_number INT,
                release_id VARCHAR(255),
                explicit BOOLEAN,
                disc_number INT,
                preview_url TEXT,
                updated_on DATETIME NOT NULL,
                FOREIGN KEY (release_id) REFERENCES `release`(release_id)
            )
            """))

            # Create AUDIO_FEATURES table
            conn.execute(text("""
            CREATE TABLE IF NOT EXISTS audio_features (
                isrc VARCHAR(255) PRIMARY KEY,
                acousticness FLOAT,
                danceability FLOAT,
                energy FLOAT,
                instrumentalness FLOAT,
                `key` INT,
                liveness FLOAT,
                loudness FLOAT,
                mode INT,
                speechiness FLOAT,
                tempo FLOAT,
                time_signature INT,
                valence FLOAT,
                updated_on DATETIME NOT NULL,
                FOREIGN KEY (isrc) REFERENCES track(isrc)
            )
            """))

            # Create ARTIST_TRACK table
            conn.execute(text("""
            CREATE TABLE IF NOT EXISTS artist_track (
                track_id VARCHAR(255),
                artist_id VARCHAR(255),
                updated_on DATETIME NOT NULL,
                PRIMARY KEY (track_id, artist_id),
                FOREIGN KEY (track_id) REFERENCES track(track_id),
                FOREIGN KEY (artist_id) REFERENCES artist(artist_id)
            )
            """))

            # Create ARTIST_RELEASE table
            conn.execute(text("""
            CREATE TABLE IF NOT EXISTS artist_release (
                release_id VARCHAR(255),
                artist_id VARCHAR(255),
                updated_on DATETIME NOT NULL,
                PRIMARY KEY (release_id, artist_id),
                FOREIGN KEY (release_id) REFERENCES `release`(release_id),
                FOREIGN KEY (artist_id) REFERENCES artist(artist_id)
            )
            """))
            
            print("Database schema created successfully!")
    except Exception as e:
        print(f"Error creating database schema: {str(e)}")
        raise

# %%
"""# At the start of your script
def optimize_mysql_connection(engine):
    with engine.connect() as conn:
        # Disable various checks temporarily
        conn.execute(text("SET UNIQUE_CHECKS=0"))
        conn.execute(text("SET FOREIGN_KEY_CHECKS=0"))
        conn.execute(text("SET SQL_MODE='NO_AUTO_VALUE_ON_ZERO'"))
        
        # Set bulk insert optimizations
        conn.execute(text("SET autocommit=0"))

# At the end of your imports
def restore_mysql_settings(engine):
    with engine.connect() as conn:
        # Re-enable checks
        conn.execute(text("SET UNIQUE_CHECKS=1"))
        conn.execute(text("SET FOREIGN_KEY_CHECKS=1"))
        conn.execute(text("SET SQL_MODE='NO_ENGINE_SUBSTITUTION'"))
        conn.execute(text("SET autocommit=1"))"""

# %%
def import_artists(engine):
    """Import artist data with optimized bulk loading and proper parameter binding"""
    try:
        print("Importing artists...")
        df = pd.read_csv('sp_artist.csv')
        df = clean_dataframe(df)
        df['updated_on'] = df['updated_on'].dt.strftime('%Y-%m-%d %H:%M:%S')
        
        chunk_size = 50000
        total_rows = len(df)
        
        with engine.connect() as conn:
            trans = conn.begin()
            try:
                for i in range(0, total_rows, chunk_size):
                    chunk = df.iloc[i:i + chunk_size]
                    
                    # Use parameterized query instead of string formatting
                    insert_stmt = text("""
                        INSERT IGNORE INTO artist (artist_id, artist_name, updated_on)
                        VALUES (:artist_id, :artist_name, :updated_on)
                    """)
                    
                    # Convert chunk to list of dictionaries for parameter binding
                    records = chunk.to_dict('records')
                    conn.execute(insert_stmt, records)
                    
                    print(f"Processed {min(i + chunk_size, total_rows)} out of {total_rows} artists")
                
                trans.commit()
                print("Artists imported successfully")
                
            except Exception as e:
                trans.rollback()
                raise e
                
    except Exception as e:
        print(f"Error importing artists: {str(e)}")
        raise

# %%
def main():
    """Main function to create schema and import data"""
    try:
        engine = create_mysql_engine()
        
        # Import data table by table
        import_artists(engine)
        
        print("All data imported successfully!")
    except Exception as e:
        print(f"Error in main execution: {str(e)}")
        raise

if __name__ == "__main__":
    main()
# Out:
# Importing artists...
# Processed 50000 out of 676911 artists
# Processed 100000 out of 676911 artists
# Processed 150000 out of 676911 artists
# Processed 200000 out of 676911 artists
# Processed 250000 out of 676911 artists
# Processed 300000 out of 676911 artists
# Processed 350000 out of 676911 artists
# Processed 400000 out of 676911 artists
# Processed 450000 out of 676911 artists
# Processed 500000 out of 676911 artists
# Processed 550000 out of 676911 artists
# Processed 600000 out of 676911 artists
# Processed 650000 out of 676911 artists
# Processed 676911 out of 676911 artists
# Artists imported successfully
# All data imported successfully!

# %%
def import_releases(engine):
    """Import release data with optimized bulk loading and proper parameter binding"""
    try:
        print("Importing releases...")
        df = pd.read_csv('sp_release.csv')
        df = clean_dataframe(df)
        df['updated_on'] = pd.to_datetime(df['updated_on']).dt.strftime('%Y-%m-%d %H:%M:%S')
        
        # Ensure release_date is in correct format
        df['release_date'] = pd.to_datetime(df['release_date']).dt.strftime('%Y-%m-%d')
        
        # Handle potential NaN values in numeric columns
        df['popularity'] = df['popularity'].fillna(0).astype(int)
        df['total_tracks'] = df['total_tracks'].fillna(0).astype(int)
        
        chunk_size = 50000
        total_rows = len(df)
        
        with engine.connect() as conn:
            trans = conn.begin()
            try:
                for i in range(0, total_rows, chunk_size):
                    chunk = df.iloc[i:i + chunk_size]
                    
                    # Convert chunk to list of dictionaries and clean data
                    records = []
                    for _, row in chunk.iterrows():
                        record = {
                            'release_id': str(row['release_id']),
                            'release_title': str(row['release_title']).replace("'", "''"),
                            'release_date': row['release_date'],
                            'upc': str(row['upc']) if pd.notna(row['upc']) else None,
                            'popularity': int(row['popularity']),
                            'total_tracks': int(row['total_tracks']),
                            'album_type': str(row['album_type']),
                            'release_img': str(row['release_img']),
                            'label_name': str(row['label_name']).replace("'", "''"),
                            'updated_on': row['updated_on']
                        }
                        records.append(record)
                    
                    # Use parameterized query
                    insert_stmt = text("""
                        INSERT IGNORE INTO `release` 
                        (release_id, release_title, release_date, upc, popularity,
                         total_tracks, album_type, release_img, label_name, updated_on)
                        VALUES 
                        (:release_id, :release_title, :release_date, :upc, :popularity,
                         :total_tracks, :album_type, :release_img, :label_name, :updated_on)
                    """)
                    
                    # Execute with parameter binding
                    conn.execute(insert_stmt, records)
                    
                    print(f"Processed {min(i + chunk_size, total_rows)} out of {total_rows} releases")
                
                trans.commit()
                print("Releases imported successfully")
                
            except Exception as e:
                trans.rollback()
                print(f"Transaction error: {str(e)}")
                raise e
                
    except Exception as e:
        print(f"Error importing releases: {str(e)}")
        print(f"Error details: {str(e.__cause__)}")
        raise

# %%
def main():
    """Main function to create schema and import data"""
    try:
        engine = create_mysql_engine()
        
        # Import data table by table

        import_releases(engine)

        print("All data imported successfully!")
    except Exception as e:
        print(f"Error in main execution: {str(e)}")
        raise

if __name__ == "__main__":
    main()
# Out:
# Importing releases...
# Processed 50000 out of 713563 releases
# Processed 100000 out of 713563 releases
# Processed 150000 out of 713563 releases
# Processed 200000 out of 713563 releases
# Processed 250000 out of 713563 releases
# Processed 300000 out of 713563 releases
# Processed 350000 out of 713563 releases
# Processed 400000 out of 713563 releases
# Processed 450000 out of 713563 releases
# Processed 500000 out of 713563 releases
# Processed 550000 out of 713563 releases
# Processed 600000 out of 713563 releases
# Processed 650000 out of 713563 releases
# Processed 700000 out of 713563 releases
# Processed 713563 out of 713563 releases
# Releases imported successfully
# All data imported successfully!

# %%
def import_tracks(engine):
    """Import track data with parameter binding"""
    try:
        print("Importing tracks...")
        df = pd.read_csv('sp_track.csv')
        df = clean_dataframe(df)
        df['updated_on'] = pd.to_datetime(df['updated_on']).dt.strftime('%Y-%m-%d %H:%M:%S')
        df['explicit'] = df['explicit'].map({'f': False, 't': True})
        
        chunk_size = 10000
        total_rows = len(df)
        
        with engine.connect() as conn:
            trans = conn.begin()
            try:
                for i in range(0, total_rows, chunk_size):
                    chunk = df.iloc[i:i + chunk_size]
                    
                    records = [{
                        'track_id': str(row['track_id']),
                        'track_title': str(row['track_title']).replace("'", "''"),
                        'duration_ms': int(row['duration_ms']),
                        'isrc': str(row['isrc']),
                        'track_number': int(row['track_number']),
                        'release_id': str(row['release_id']),
                        'explicit': bool(row['explicit']),
                        'disc_number': int(row['disc_number']),
                        'preview_url': str(row['preview_url']),
                        'updated_on': row['updated_on']
                    } for _, row in chunk.iterrows()]
                    
                    insert_stmt = text("""
                        INSERT IGNORE INTO track 
                        (track_id, track_title, duration_ms, isrc, track_number,
                         release_id, explicit, disc_number, preview_url, updated_on)
                        VALUES 
                        (:track_id, :track_title, :duration_ms, :isrc, :track_number,
                         :release_id, :explicit, :disc_number, :preview_url, :updated_on)
                    """)
                    
                    conn.execute(insert_stmt, records)
                    print(f"Processed {min(i + chunk_size, total_rows)} out of {total_rows} tracks")
                
                trans.commit()
                print("Tracks imported successfully")
                
            except Exception as e:
                trans.rollback()
                raise e
                
    except Exception as e:
        print(f"Error importing tracks: {str(e)}")
        raise

# %%
def main():
    """Main function to create schema and import data"""
    try:
        engine = create_mysql_engine()
        
        # Import data table by table
        import_tracks(engine)

        print("All data imported successfully!")
    except Exception as e:
        print(f"Error in main execution: {str(e)}")
        raise

if __name__ == "__main__":
    main()
# Out:
# Importing tracks...
# Processed 10000 out of 5777707 tracks
# Processed 20000 out of 5777707 tracks
# Processed 30000 out of 5777707 tracks
# Processed 40000 out of 5777707 tracks
# Processed 50000 out of 5777707 tracks
# Processed 60000 out of 5777707 tracks
# Processed 70000 out of 5777707 tracks
# Processed 80000 out of 5777707 tracks
# Processed 90000 out of 5777707 tracks
# Processed 100000 out of 5777707 tracks
# Processed 110000 out of 5777707 tracks
# Processed 120000 out of 5777707 tracks
# Processed 130000 out of 5777707 tracks
# Processed 140000 out of 5777707 tracks
# Processed 150000 out of 5777707 tracks
# Processed 160000 out of 5777707 tracks
# Processed 170000 out of 5777707 tracks
# Processed 180000 out of 5777707 tracks
# Processed 190000 out of 5777707 tracks
# Processed 200000 out of 5777707 tracks
# Processed 210000 out of 5777707 tracks
# Processed 220000 out of 5777707 tracks
# Processed 230000 out of 5777707 tracks
# Processed 240000 out of 5777707 tracks
# Processed 250000 out of 5777707 tracks
# Processed 260000 out of 5777707 tracks
# Processed 270000 out of 5777707 tracks
# Processed 280000 out of 5777707 tracks
# Processed 290000 out of 5777707 tracks
# Processed 300000 out of 5777707 tracks
# Processed 310000 out of 5777707 tracks
# Processed 320000 out of 5777707 tracks
# Processed 330000 out of 5777707 tracks
# Processed 340000 out of 5777707 tracks
# Processed 350000 out of 5777707 tracks
# Processed 360000 out of 5777707 tracks
# Processed 370000 out of 5777707 tracks
# Processed 380000 out of 5777707 tracks
# Processed 390000 out of 5777707 tracks
# Processed 400000 out of 5777707 tracks
# Processed 410000 out of 5777707 tracks
# Processed 420000 out of 5777707 tracks
# Processed 430000 out of 5777707 tracks
# Processed 440000 out of 5777707 tracks
# Processed 450000 out of 5777707 tracks
# Processed 460000 out of 5777707 tracks
# Processed 470000 out of 5777707 tracks
# Processed 480000 out of 5777707 tracks
# Processed 490000 out of 5777707 tracks
# Processed 500000 out of 5777707 tracks
# Processed 510000 out of 5777707 tracks
# Processed 520000 out of 5777707 tracks
# Processed 530000 out of 5777707 tracks
# Processed 540000 out of 5777707 tracks
# Processed 550000 out of 5777707 tracks
# Processed 560000 out of 5777707 tracks
# Processed 570000 out of 5777707 tracks
# Processed 580000 out of 5777707 tracks
# Processed 590000 out of 5777707 tracks
# Processed 600000 out of 5777707 tracks
# Processed 610000 out of 5777707 tracks
# Processed 620000 out of 5777707 tracks
# Processed 630000 out of 5777707 tracks
# Processed 640000 out of 5777707 tracks
# Processed 650000 out of 5777707 tracks
# Processed 660000 out of 5777707 tracks
# Processed 670000 out of 5777707 tracks
# Processed 680000 out of 5777707 tracks
# Processed 690000 out of 5777707 tracks
# Processed 700000 out of 5777707 tracks
# Processed 710000 out of 5777707 tracks
# Processed 720000 out of 5777707 tracks
# Processed 730000 out of 5777707 tracks
# Processed 740000 out of 5777707 tracks
# Processed 750000 out of 5777707 tracks
# Processed 760000 out of 5777707 tracks
# Processed 770000 out of 5777707 tracks
# Processed 780000 out of 5777707 tracks
# Processed 790000 out of 5777707 tracks
# Processed 800000 out of 5777707 tracks
# Processed 810000 out of 5777707 tracks
# Processed 820000 out of 5777707 tracks
# Processed 830000 out of 5777707 tracks
# Processed 840000 out of 5777707 tracks
# Processed 850000 out of 5777707 tracks
# Processed 860000 out of 5777707 tracks
# Processed 870000 out of 5777707 tracks
# Processed 880000 out of 5777707 tracks
# Processed 890000 out of 5777707 tracks
# Processed 900000 out of 5777707 tracks
# Processed 910000 out of 5777707 tracks
# Processed 920000 out of 5777707 tracks
# Processed 930000 out of 5777707 tracks
# Processed 940000 out of 5777707 tracks
# Processed 950000 out of 5777707 tracks
# Processed 960000 out of 5777707 tracks
# Processed 970000 out of 5777707 tracks
# Processed 980000 out of 5777707 tracks
# Processed 990000 out of 5777707 tracks
# Processed 1000000 out of 5777707 tracks
# Processed 1010000 out of 5777707 tracks
# Processed 1020000 out of 5777707 tracks
# Processed 1030000 out of 5777707 tracks
# Processed 1040000 out of 5777707 tracks
# Processed 1050000 out of 5777707 tracks
# Processed 1060000 out of 5777707 tracks
# Processed 1070000 out of 5777707 tracks
# Processed 1080000 out of 5777707 tracks
# Processed 1090000 out of 5777707 tracks
# Processed 1100000 out of 5777707 tracks
# Processed 1110000 out of 5777707 tracks
# Processed 1120000 out of 5777707 tracks
# Processed 1130000 out of 5777707 tracks
# Processed 1140000 out of 5777707 tracks
# Processed 1150000 out of 5777707 tracks
# Processed 1160000 out of 5777707 tracks
# Processed 1170000 out of 5777707 tracks
# Processed 1180000 out of 5777707 tracks
# Processed 1190000 out of 5777707 tracks
# Processed 1200000 out of 5777707 tracks
# Processed 1210000 out of 5777707 tracks
# Processed 1220000 out of 5777707 tracks
# Processed 1230000 out of 5777707 tracks
# Processed 1240000 out of 5777707 tracks
# Processed 1250000 out of 5777707 tracks
# Processed 1260000 out of 5777707 tracks
# Processed 1270000 out of 5777707 tracks
# Processed 1280000 out of 5777707 tracks
# Processed 1290000 out of 5777707 tracks
# Processed 1300000 out of 5777707 tracks
# Processed 1310000 out of 5777707 tracks
# Processed 1320000 out of 5777707 tracks
# Processed 1330000 out of 5777707 tracks
# Processed 1340000 out of 5777707 tracks
# Processed 1350000 out of 5777707 tracks
# Processed 1360000 out of 5777707 tracks
# Processed 1370000 out of 5777707 tracks
# Processed 1380000 out of 5777707 tracks
# Processed 1390000 out of 5777707 tracks
# Processed 1400000 out of 5777707 tracks
# Processed 1410000 out of 5777707 tracks
# Processed 1420000 out of 5777707 tracks
# Processed 1430000 out of 5777707 tracks
# Processed 1440000 out of 5777707 tracks
# Processed 1450000 out of 5777707 tracks
# Processed 1460000 out of 5777707 tracks
# Processed 1470000 out of 5777707 tracks
# Processed 1480000 out of 5777707 tracks
# Processed 1490000 out of 5777707 tracks
# Processed 1500000 out of 5777707 tracks
# Processed 1510000 out of 5777707 tracks
# Processed 1520000 out of 5777707 tracks
# Processed 1530000 out of 5777707 tracks
# Processed 1540000 out of 5777707 tracks
# Processed 1550000 out of 5777707 tracks
# Processed 1560000 out of 5777707 tracks
# Processed 1570000 out of 5777707 tracks
# Processed 1580000 out of 5777707 tracks
# Processed 1590000 out of 5777707 tracks
# Processed 1600000 out of 5777707 tracks
# Processed 1610000 out of 5777707 tracks
# Processed 1620000 out of 5777707 tracks
# Processed 1630000 out of 5777707 tracks
# Processed 1640000 out of 5777707 tracks
# Processed 1650000 out of 5777707 tracks
# Processed 1660000 out of 5777707 tracks
# Processed 1670000 out of 5777707 tracks
# Processed 1680000 out of 5777707 tracks
# Processed 1690000 out of 5777707 tracks
# Processed 1700000 out of 5777707 tracks
# Processed 1710000 out of 5777707 tracks
# Processed 1720000 out of 5777707 tracks
# Processed 1730000 out of 5777707 tracks
# Processed 1740000 out of 5777707 tracks
# Processed 1750000 out of 5777707 tracks
# Processed 1760000 out of 5777707 tracks
# Processed 1770000 out of 5777707 tracks
# Processed 1780000 out of 5777707 tracks
# Processed 1790000 out of 5777707 tracks
# Processed 1800000 out of 5777707 tracks
# Processed 1810000 out of 5777707 tracks
# Processed 1820000 out of 5777707 tracks
# Processed 1830000 out of 5777707 tracks
# Processed 1840000 out of 5777707 tracks
# Processed 1850000 out of 5777707 tracks
# Processed 1860000 out of 5777707 tracks
# Processed 1870000 out of 5777707 tracks
# Processed 1880000 out of 5777707 tracks
# Processed 1890000 out of 5777707 tracks
# Processed 1900000 out of 5777707 tracks
# Processed 1910000 out of 5777707 tracks
# Processed 1920000 out of 5777707 tracks
# Processed 1930000 out of 5777707 tracks
# Processed 1940000 out of 5777707 tracks
# Processed 1950000 out of 5777707 tracks
# Processed 1960000 out of 5777707 tracks
# Processed 1970000 out of 5777707 tracks
# Processed 1980000 out of 5777707 tracks
# Processed 1990000 out of 5777707 tracks
# Processed 2000000 out of 5777707 tracks
# Processed 2010000 out of 5777707 tracks
# Processed 2020000 out of 5777707 tracks
# Processed 2030000 out of 5777707 tracks
# Processed 2040000 out of 5777707 tracks
# Processed 2050000 out of 5777707 tracks
# Processed 2060000 out of 5777707 tracks
# Processed 2070000 out of 5777707 tracks
# Processed 2080000 out of 5777707 tracks
# Processed 2090000 out of 5777707 tracks
# Processed 2100000 out of 5777707 tracks
# Processed 2110000 out of 5777707 tracks
# Processed 2120000 out of 5777707 tracks
# Processed 2130000 out of 5777707 tracks
# Processed 2140000 out of 5777707 tracks
# Processed 2150000 out of 5777707 tracks
# Processed 2160000 out of 5777707 tracks
# Processed 2170000 out of 5777707 tracks
# Processed 2180000 out of 5777707 tracks
# Processed 2190000 out of 5777707 tracks
# Processed 2200000 out of 5777707 tracks
# Processed 2210000 out of 5777707 tracks
# Processed 2220000 out of 5777707 tracks
# Processed 2230000 out of 5777707 tracks
# Processed 2240000 out of 5777707 tracks
# Processed 2250000 out of 5777707 tracks
# Processed 2260000 out of 5777707 tracks
# Processed 2270000 out of 5777707 tracks
# Processed 2280000 out of 5777707 tracks
# Processed 2290000 out of 5777707 tracks
# Processed 2300000 out of 5777707 tracks
# Processed 2310000 out of 5777707 tracks
# Processed 2320000 out of 5777707 tracks
# Processed 2330000 out of 5777707 tracks
# Processed 2340000 out of 5777707 tracks
# Processed 2350000 out of 5777707 tracks
# Processed 2360000 out of 5777707 tracks
# Processed 2370000 out of 5777707 tracks
# Processed 2380000 out of 5777707 tracks
# Processed 2390000 out of 5777707 tracks
# Processed 2400000 out of 5777707 tracks
# Processed 2410000 out of 5777707 tracks
# Processed 2420000 out of 5777707 tracks
# Processed 2430000 out of 5777707 tracks
# Processed 2440000 out of 5777707 tracks
# Processed 2450000 out of 5777707 tracks
# Processed 2460000 out of 5777707 tracks
# Processed 2470000 out of 5777707 tracks
# Processed 2480000 out of 5777707 tracks
# Processed 2490000 out of 5777707 tracks
# Processed 2500000 out of 5777707 tracks
# Processed 2510000 out of 5777707 tracks
# Processed 2520000 out of 5777707 tracks
# Processed 2530000 out of 5777707 tracks
# Processed 2540000 out of 5777707 tracks
# Processed 2550000 out of 5777707 tracks
# Processed 2560000 out of 5777707 tracks
# Processed 2570000 out of 5777707 tracks
# Processed 2580000 out of 5777707 tracks
# Processed 2590000 out of 5777707 tracks
# Processed 2600000 out of 5777707 tracks
# Processed 2610000 out of 5777707 tracks
# Processed 2620000 out of 5777707 tracks
# Processed 2630000 out of 5777707 tracks
# Processed 2640000 out of 5777707 tracks
# Processed 2650000 out of 5777707 tracks
# Processed 2660000 out of 5777707 tracks
# Processed 2670000 out of 5777707 tracks
# Processed 2680000 out of 5777707 tracks
# Processed 2690000 out of 5777707 tracks
# Processed 2700000 out of 5777707 tracks
# Processed 2710000 out of 5777707 tracks
# Processed 2720000 out of 5777707 tracks
# Processed 2730000 out of 5777707 tracks
# Processed 2740000 out of 5777707 tracks
# Processed 2750000 out of 5777707 tracks
# Processed 2760000 out of 5777707 tracks
# Processed 2770000 out of 5777707 tracks
# Processed 2780000 out of 5777707 tracks
# Processed 2790000 out of 5777707 tracks
# Processed 2800000 out of 5777707 tracks
# Processed 2810000 out of 5777707 tracks
# Processed 2820000 out of 5777707 tracks
# Processed 2830000 out of 5777707 tracks
# Processed 2840000 out of 5777707 tracks
# Processed 2850000 out of 5777707 tracks
# Processed 2860000 out of 5777707 tracks
# Processed 2870000 out of 5777707 tracks
# Processed 2880000 out of 5777707 tracks
# Processed 2890000 out of 5777707 tracks
# Processed 2900000 out of 5777707 tracks
# Processed 2910000 out of 5777707 tracks
# Processed 2920000 out of 5777707 tracks
# Processed 2930000 out of 5777707 tracks
# Processed 2940000 out of 5777707 tracks
# Processed 2950000 out of 5777707 tracks
# Processed 2960000 out of 5777707 tracks
# Processed 2970000 out of 5777707 tracks
# Processed 2980000 out of 5777707 tracks
# Processed 2990000 out of 5777707 tracks
# Processed 3000000 out of 5777707 tracks
# Processed 3010000 out of 5777707 tracks
# Processed 3020000 out of 5777707 tracks
# Processed 3030000 out of 5777707 tracks
# Processed 3040000 out of 5777707 tracks
# Processed 3050000 out of 5777707 tracks
# Processed 3060000 out of 5777707 tracks
# Processed 3070000 out of 5777707 tracks
# Processed 3080000 out of 5777707 tracks
# Processed 3090000 out of 5777707 tracks
# Processed 3100000 out of 5777707 tracks
# Processed 3110000 out of 5777707 tracks
# Processed 3120000 out of 5777707 tracks
# Processed 3130000 out of 5777707 tracks
# Processed 3140000 out of 5777707 tracks
# Processed 3150000 out of 5777707 tracks
# Processed 3160000 out of 5777707 tracks
# Processed 3170000 out of 5777707 tracks
# Processed 3180000 out of 5777707 tracks
# Processed 3190000 out of 5777707 tracks
# Processed 3200000 out of 5777707 tracks
# Processed 3210000 out of 5777707 tracks
# Processed 3220000 out of 5777707 tracks
# Processed 3230000 out of 5777707 tracks
# Processed 3240000 out of 5777707 tracks
# Processed 3250000 out of 5777707 tracks
# Processed 3260000 out of 5777707 tracks
# Processed 3270000 out of 5777707 tracks
# Processed 3280000 out of 5777707 tracks
# Processed 3290000 out of 5777707 tracks
# Processed 3300000 out of 5777707 tracks
# Processed 3310000 out of 5777707 tracks
# Processed 3320000 out of 5777707 tracks
# Processed 3330000 out of 5777707 tracks
# Processed 3340000 out of 5777707 tracks
# Processed 3350000 out of 5777707 tracks
# Processed 3360000 out of 5777707 tracks
# Processed 3370000 out of 5777707 tracks
# Processed 3380000 out of 5777707 tracks
# Processed 3390000 out of 5777707 tracks
# Processed 3400000 out of 5777707 tracks
# Processed 3410000 out of 5777707 tracks
# Processed 3420000 out of 5777707 tracks
# Processed 3430000 out of 5777707 tracks
# Processed 3440000 out of 5777707 tracks
# Processed 3450000 out of 5777707 tracks
# Processed 3460000 out of 5777707 tracks
# Processed 3470000 out of 5777707 tracks
# Processed 3480000 out of 5777707 tracks
# Processed 3490000 out of 5777707 tracks
# Processed 3500000 out of 5777707 tracks
# Processed 3510000 out of 5777707 tracks
# Processed 3520000 out of 5777707 tracks
# Processed 3530000 out of 5777707 tracks
# Processed 3540000 out of 5777707 tracks
# Processed 3550000 out of 5777707 tracks
# Processed 3560000 out of 5777707 tracks
# Processed 3570000 out of 5777707 tracks
# Processed 3580000 out of 5777707 tracks
# Processed 3590000 out of 5777707 tracks
# Processed 3600000 out of 5777707 tracks
# Processed 3610000 out of 5777707 tracks
# Processed 3620000 out of 5777707 tracks
# Processed 3630000 out of 5777707 tracks
# Processed 3640000 out of 5777707 tracks
# Processed 3650000 out of 5777707 tracks
# Processed 3660000 out of 5777707 tracks
# Processed 3670000 out of 5777707 tracks
# Processed 3680000 out of 5777707 tracks
# Processed 3690000 out of 5777707 tracks
# Processed 3700000 out of 5777707 tracks
# Processed 3710000 out of 5777707 tracks
# Processed 3720000 out of 5777707 tracks
# Processed 3730000 out of 5777707 tracks
# Processed 3740000 out of 5777707 tracks
# Processed 3750000 out of 5777707 tracks
# Processed 3760000 out of 5777707 tracks
# Processed 3770000 out of 5777707 tracks
# Processed 3780000 out of 5777707 tracks
# Processed 3790000 out of 5777707 tracks
# Processed 3800000 out of 5777707 tracks
# Processed 3810000 out of 5777707 tracks
# Processed 3820000 out of 5777707 tracks
# Processed 3830000 out of 5777707 tracks
# Processed 3840000 out of 5777707 tracks
# Processed 3850000 out of 5777707 tracks
# Processed 3860000 out of 5777707 tracks
# Processed 3870000 out of 5777707 tracks
# Processed 3880000 out of 5777707 tracks
# Processed 3890000 out of 5777707 tracks
# Processed 3900000 out of 5777707 tracks
# Processed 3910000 out of 5777707 tracks
# Processed 3920000 out of 5777707 tracks
# Processed 3930000 out of 5777707 tracks
# Processed 3940000 out of 5777707 tracks
# Processed 3950000 out of 5777707 tracks
# Processed 3960000 out of 5777707 tracks
# Processed 3970000 out of 5777707 tracks
# Processed 3980000 out of 5777707 tracks
# Processed 3990000 out of 5777707 tracks
# Processed 4000000 out of 5777707 tracks
# Processed 4010000 out of 5777707 tracks
# Processed 4020000 out of 5777707 tracks
# Processed 4030000 out of 5777707 tracks
# Processed 4040000 out of 5777707 tracks
# Processed 4050000 out of 5777707 tracks
# Processed 4060000 out of 5777707 tracks
# Processed 4070000 out of 5777707 tracks
# Processed 4080000 out of 5777707 tracks
# Processed 4090000 out of 5777707 tracks
# Processed 4100000 out of 5777707 tracks
# Processed 4110000 out of 5777707 tracks
# Processed 4120000 out of 5777707 tracks
# Processed 4130000 out of 5777707 tracks
# Processed 4140000 out of 5777707 tracks
# Processed 4150000 out of 5777707 tracks
# Processed 4160000 out of 5777707 tracks
# Processed 4170000 out of 5777707 tracks
# Processed 4180000 out of 5777707 tracks
# Processed 4190000 out of 5777707 tracks
# Processed 4200000 out of 5777707 tracks
# Processed 4210000 out of 5777707 tracks
# Processed 4220000 out of 5777707 tracks
# Processed 4230000 out of 5777707 tracks
# Processed 4240000 out of 5777707 tracks
# Processed 4250000 out of 5777707 tracks
# Processed 4260000 out of 5777707 tracks
# Processed 4270000 out of 5777707 tracks
# Processed 4280000 out of 5777707 tracks
# Processed 4290000 out of 5777707 tracks
# Processed 4300000 out of 5777707 tracks
# Processed 4310000 out of 5777707 tracks
# Processed 4320000 out of 5777707 tracks
# Processed 4330000 out of 5777707 tracks
# Processed 4340000 out of 5777707 tracks
# Processed 4350000 out of 5777707 tracks
# Processed 4360000 out of 5777707 tracks
# Processed 4370000 out of 5777707 tracks
# Processed 4380000 out of 5777707 tracks
# Processed 4390000 out of 5777707 tracks
# Processed 4400000 out of 5777707 tracks
# Processed 4410000 out of 5777707 tracks
# Processed 4420000 out of 5777707 tracks
# Processed 4430000 out of 5777707 tracks
# Processed 4440000 out of 5777707 tracks
# Processed 4450000 out of 5777707 tracks
# Processed 4460000 out of 5777707 tracks
# Processed 4470000 out of 5777707 tracks
# Processed 4480000 out of 5777707 tracks
# Processed 4490000 out of 5777707 tracks
# Processed 4500000 out of 5777707 tracks
# Processed 4510000 out of 5777707 tracks
# Processed 4520000 out of 5777707 tracks
# Processed 4530000 out of 5777707 tracks
# Processed 4540000 out of 5777707 tracks
# Processed 4550000 out of 5777707 tracks
# Processed 4560000 out of 5777707 tracks
# Processed 4570000 out of 5777707 tracks
# Processed 4580000 out of 5777707 tracks
# Processed 4590000 out of 5777707 tracks
# Processed 4600000 out of 5777707 tracks
# Processed 4610000 out of 5777707 tracks
# Processed 4620000 out of 5777707 tracks
# Processed 4630000 out of 5777707 tracks
# Processed 4640000 out of 5777707 tracks
# Processed 4650000 out of 5777707 tracks
# Processed 4660000 out of 5777707 tracks
# Processed 4670000 out of 5777707 tracks
# Processed 4680000 out of 5777707 tracks
# Processed 4690000 out of 5777707 tracks
# Processed 4700000 out of 5777707 tracks
# Processed 4710000 out of 5777707 tracks
# Processed 4720000 out of 5777707 tracks
# Processed 4730000 out of 5777707 tracks
# Processed 4740000 out of 5777707 tracks
# Processed 4750000 out of 5777707 tracks
# Processed 4760000 out of 5777707 tracks
# Processed 4770000 out of 5777707 tracks
# Processed 4780000 out of 5777707 tracks
# Processed 4790000 out of 5777707 tracks
# Processed 4800000 out of 5777707 tracks
# Processed 4810000 out of 5777707 tracks
# Processed 4820000 out of 5777707 tracks
# Processed 4830000 out of 5777707 tracks
# Processed 4840000 out of 5777707 tracks
# Processed 4850000 out of 5777707 tracks
# Processed 4860000 out of 5777707 tracks
# Processed 4870000 out of 5777707 tracks
# Processed 4880000 out of 5777707 tracks
# Processed 4890000 out of 5777707 tracks
# Processed 4900000 out of 5777707 tracks
# Processed 4910000 out of 5777707 tracks
# Processed 4920000 out of 5777707 tracks
# Processed 4930000 out of 5777707 tracks
# Processed 4940000 out of 5777707 tracks
# Processed 4950000 out of 5777707 tracks
# Processed 4960000 out of 5777707 tracks
# Processed 4970000 out of 5777707 tracks
# Processed 4980000 out of 5777707 tracks
# Processed 4990000 out of 5777707 tracks
# Processed 5000000 out of 5777707 tracks
# Processed 5010000 out of 5777707 tracks
# Processed 5020000 out of 5777707 tracks
# Processed 5030000 out of 5777707 tracks
# Processed 5040000 out of 5777707 tracks
# Processed 5050000 out of 5777707 tracks
# Processed 5060000 out of 5777707 tracks
# Processed 5070000 out of 5777707 tracks
# Processed 5080000 out of 5777707 tracks
# Processed 5090000 out of 5777707 tracks
# Processed 5100000 out of 5777707 tracks
# Processed 5110000 out of 5777707 tracks
# Processed 5120000 out of 5777707 tracks
# Processed 5130000 out of 5777707 tracks
# Processed 5140000 out of 5777707 tracks
# Processed 5150000 out of 5777707 tracks
# Processed 5160000 out of 5777707 tracks
# Processed 5170000 out of 5777707 tracks
# Processed 5180000 out of 5777707 tracks
# Processed 5190000 out of 5777707 tracks
# Processed 5200000 out of 5777707 tracks
# Processed 5210000 out of 5777707 tracks
# Processed 5220000 out of 5777707 tracks
# Processed 5230000 out of 5777707 tracks
# Processed 5240000 out of 5777707 tracks
# Processed 5250000 out of 5777707 tracks
# Processed 5260000 out of 5777707 tracks
# Processed 5270000 out of 5777707 tracks
# Processed 5280000 out of 5777707 tracks
# Processed 5290000 out of 5777707 tracks
# Processed 5300000 out of 5777707 tracks
# Processed 5310000 out of 5777707 tracks
# Processed 5320000 out of 5777707 tracks
# Processed 5330000 out of 5777707 tracks
# Processed 5340000 out of 5777707 tracks
# Processed 5350000 out of 5777707 tracks
# Processed 5360000 out of 5777707 tracks
# Processed 5370000 out of 5777707 tracks
# Processed 5380000 out of 5777707 tracks
# Processed 5390000 out of 5777707 tracks
# Processed 5400000 out of 5777707 tracks
# Processed 5410000 out of 5777707 tracks
# Processed 5420000 out of 5777707 tracks
# Processed 5430000 out of 5777707 tracks
# Processed 5440000 out of 5777707 tracks
# Processed 5450000 out of 5777707 tracks
# Processed 5460000 out of 5777707 tracks
# Processed 5470000 out of 5777707 tracks
# Processed 5480000 out of 5777707 tracks
# Processed 5490000 out of 5777707 tracks
# Processed 5500000 out of 5777707 tracks
# Processed 5510000 out of 5777707 tracks
# Processed 5520000 out of 5777707 tracks
# Processed 5530000 out of 5777707 tracks
# Processed 5540000 out of 5777707 tracks
# Processed 5550000 out of 5777707 tracks
# Processed 5560000 out of 5777707 tracks
# Processed 5570000 out of 5777707 tracks
# Processed 5580000 out of 5777707 tracks
# Processed 5590000 out of 5777707 tracks
# Processed 5600000 out of 5777707 tracks
# Processed 5610000 out of 5777707 tracks
# Processed 5620000 out of 5777707 tracks
# Processed 5630000 out of 5777707 tracks
# Processed 5640000 out of 5777707 tracks
# Processed 5650000 out of 5777707 tracks
# Processed 5660000 out of 5777707 tracks
# Processed 5670000 out of 5777707 tracks
# Processed 5680000 out of 5777707 tracks
# Processed 5690000 out of 5777707 tracks
# Processed 5700000 out of 5777707 tracks
# Processed 5710000 out of 5777707 tracks
# Processed 5720000 out of 5777707 tracks
# Processed 5730000 out of 5777707 tracks
# Processed 5740000 out of 5777707 tracks
# Processed 5750000 out of 5777707 tracks
# Processed 5760000 out of 5777707 tracks
# Processed 5770000 out of 5777707 tracks
# Processed 5777707 out of 5777707 tracks
# Tracks imported successfully
# All data imported successfully!

# %%
def import_audio_features(engine):
    """Import audio features data with parameter binding"""
    try:
        print("Importing audio features...")
        df = pd.read_csv('audio_features.csv')
        df = clean_dataframe(df)
        df['updated_on'] = pd.to_datetime(df['updated_on']).dt.strftime('%Y-%m-%d %H:%M:%S')
        
        chunk_size = 1000
        total_rows = len(df)
        
        with engine.connect() as conn:
            trans = conn.begin()
            try:
                for i in range(0, total_rows, chunk_size):
                    chunk = df.iloc[i:i + chunk_size]
                    
                    records = [{
                        'isrc': str(row['isrc']),
                        'acousticness': float(row['acousticness']),
                        'danceability': float(row['danceability']),
                        'energy': float(row['energy']),
                        'instrumentalness': float(row['instrumentalness']),
                        'key': int(row['key']),
                        'liveness': float(row['liveness']),
                        'loudness': float(row['loudness']),
                        'mode': int(row['mode']),
                        'speechiness': float(row['speechiness']),
                        'tempo': float(row['tempo']),
                        'time_signature': int(row['time_signature']),
                        'valence': float(row['valence']),
                        'updated_on': row['updated_on']
                    } for _, row in chunk.iterrows()]
                    
                    insert_stmt = text("""
                        INSERT IGNORE INTO audio_features 
                        (isrc, acousticness, danceability, energy, instrumentalness,
                         `key`, liveness, loudness, mode, speechiness, tempo,
                         time_signature, valence, updated_on)
                        VALUES 
                        (:isrc, :acousticness, :danceability, :energy, :instrumentalness,
                         :key, :liveness, :loudness, :mode, :speechiness, :tempo,
                         :time_signature, :valence, :updated_on)
                    """)
                    
                    conn.execute(insert_stmt, records)
                    print(f"Processed {min(i + chunk_size, total_rows)} out of {total_rows} audio features")
                
                trans.commit()
                print("Audio features imported successfully")
                
            except Exception as e:
                trans.rollback()
                raise e
                
    except Exception as e:
        print(f"Error importing audio features: {str(e)}")
        raise

# %%
def main():
    """Main function to create schema and import data"""
    try:
        engine = create_mysql_engine()
        
        # Import data table by table
        import_audio_features(engine)

        print("All data imported successfully!")
    except Exception as e:
        print(f"Error in main execution: {str(e)}")
        raise

if __name__ == "__main__":
    main()
# Out:
# Importing audio features...
# Processed 1000 out of 4687104 audio features
# Processed 2000 out of 4687104 audio features
# Processed 3000 out of 4687104 audio features
# Processed 4000 out of 4687104 audio features
# Processed 5000 out of 4687104 audio features
# Processed 6000 out of 4687104 audio features
# Processed 7000 out of 4687104 audio features
# Processed 8000 out of 4687104 audio features
# Processed 9000 out of 4687104 audio features
# Processed 10000 out of 4687104 audio features
# Processed 11000 out of 4687104 audio features
# Processed 12000 out of 4687104 audio features
# Processed 13000 out of 4687104 audio features
# Processed 14000 out of 4687104 audio features
# Processed 15000 out of 4687104 audio features
# Processed 16000 out of 4687104 audio features
# Processed 17000 out of 4687104 audio features
# Processed 18000 out of 4687104 audio features
# Processed 19000 out of 4687104 audio features
# Processed 20000 out of 4687104 audio features
# Processed 21000 out of 4687104 audio features
# Processed 22000 out of 4687104 audio features
# Processed 23000 out of 4687104 audio features
# Processed 24000 out of 4687104 audio features
# Processed 25000 out of 4687104 audio features
# Processed 26000 out of 4687104 audio features
# Processed 27000 out of 4687104 audio features
# Processed 28000 out of 4687104 audio features
# Processed 29000 out of 4687104 audio features
# Processed 30000 out of 4687104 audio features
# Processed 31000 out of 4687104 audio features
# Processed 32000 out of 4687104 audio features
# Processed 33000 out of 4687104 audio features
# Processed 34000 out of 4687104 audio features
# Processed 35000 out of 4687104 audio features
# Processed 36000 out of 4687104 audio features
# Processed 37000 out of 4687104 audio features
# Processed 38000 out of 4687104 audio features
# Processed 39000 out of 4687104 audio features
# Processed 40000 out of 4687104 audio features
# Processed 41000 out of 4687104 audio features
# Processed 42000 out of 4687104 audio features
# Processed 43000 out of 4687104 audio features
# Processed 44000 out of 4687104 audio features
# Processed 45000 out of 4687104 audio features
# Processed 46000 out of 4687104 audio features
# Processed 47000 out of 4687104 audio features
# Processed 48000 out of 4687104 audio features
# Processed 49000 out of 4687104 audio features
# Processed 50000 out of 4687104 audio features
# Processed 51000 out of 4687104 audio features
# Processed 52000 out of 4687104 audio features
# Processed 53000 out of 4687104 audio features
# Processed 54000 out of 4687104 audio features
# Processed 55000 out of 4687104 audio features
# Processed 56000 out of 4687104 audio features
# Processed 57000 out of 4687104 audio features
# Processed 58000 out of 4687104 audio features
# Processed 59000 out of 4687104 audio features
# Processed 60000 out of 4687104 audio features
# Processed 61000 out of 4687104 audio features
# Processed 62000 out of 4687104 audio features
# Processed 63000 out of 4687104 audio features
# Processed 64000 out of 4687104 audio features
# Processed 65000 out of 4687104 audio features
# Processed 66000 out of 4687104 audio features
# Processed 67000 out of 4687104 audio features
# Processed 68000 out of 4687104 audio features
# Processed 69000 out of 4687104 audio features
# Processed 70000 out of 4687104 audio features
# Processed 71000 out of 4687104 audio features
# Processed 72000 out of 4687104 audio features
# Processed 73000 out of 4687104 audio features
# Processed 74000 out of 4687104 audio features
# Processed 75000 out of 4687104 audio features
# Processed 76000 out of 4687104 audio features
# Processed 77000 out of 4687104 audio features
# Processed 78000 out of 4687104 audio features
# Processed 79000 out of 4687104 audio features
# Processed 80000 out of 4687104 audio features
# Processed 81000 out of 4687104 audio features
# Processed 82000 out of 4687104 audio features
# Processed 83000 out of 4687104 audio features
# Processed 84000 out of 4687104 audio features
# Processed 85000 out of 4687104 audio features
# Processed 86000 out of 4687104 audio features
# Processed 87000 out of 4687104 audio features
# Processed 88000 out of 4687104 audio features
# Processed 89000 out of 4687104 audio features
# Processed 90000 out of 4687104 audio features
# Processed 91000 out of 4687104 audio features
# Processed 92000 out of 4687104 audio features
# Processed 93000 out of 4687104 audio features
# Processed 94000 out of 4687104 audio features
# Processed 95000 out of 4687104 audio features
# Processed 96000 out of 4687104 audio features
# Processed 97000 out of 4687104 audio features
# Processed 98000 out of 4687104 audio features
# Processed 99000 out of 4687104 audio features
# Processed 100000 out of 4687104 audio features
# Processed 101000 out of 4687104 audio features
# Processed 102000 out of 4687104 audio features
# Processed 103000 out of 4687104 audio features
# Processed 104000 out of 4687104 audio features
# Processed 105000 out of 4687104 audio features
# Processed 106000 out of 4687104 audio features
# Processed 107000 out of 4687104 audio features
# Processed 108000 out of 4687104 audio features
# Processed 109000 out of 4687104 audio features
# Processed 110000 out of 4687104 audio features
# Processed 111000 out of 4687104 audio features
# Processed 112000 out of 4687104 audio features
# Processed 113000 out of 4687104 audio features
# Processed 114000 out of 4687104 audio features
# Processed 115000 out of 4687104 audio features
# Processed 116000 out of 4687104 audio features
# Processed 117000 out of 4687104 audio features
# Processed 118000 out of 4687104 audio features
# Processed 119000 out of 4687104 audio features
# Processed 120000 out of 4687104 audio features
# Processed 121000 out of 4687104 audio features
# Processed 122000 out of 4687104 audio features
# Processed 123000 out of 4687104 audio features
# Processed 124000 out of 4687104 audio features
# Processed 125000 out of 4687104 audio features
# Processed 126000 out of 4687104 audio features
# Processed 127000 out of 4687104 audio features
# Processed 128000 out of 4687104 audio features
# Processed 129000 out of 4687104 audio features
# Processed 130000 out of 4687104 audio features
# Processed 131000 out of 4687104 audio features
# Processed 132000 out of 4687104 audio features
# Processed 133000 out of 4687104 audio features
# Processed 134000 out of 4687104 audio features
# Processed 135000 out of 4687104 audio features
# Processed 136000 out of 4687104 audio features
# Processed 137000 out of 4687104 audio features
# Processed 138000 out of 4687104 audio features
# Processed 139000 out of 4687104 audio features
# Processed 140000 out of 4687104 audio features
# Processed 141000 out of 4687104 audio features
# Processed 142000 out of 4687104 audio features
# Processed 143000 out of 4687104 audio features
# Processed 144000 out of 4687104 audio features
# Processed 145000 out of 4687104 audio features
# Processed 146000 out of 4687104 audio features
# Processed 147000 out of 4687104 audio features
# Processed 148000 out of 4687104 audio features
# Processed 149000 out of 4687104 audio features
# Processed 150000 out of 4687104 audio features
# Processed 151000 out of 4687104 audio features
# Processed 152000 out of 4687104 audio features
# Processed 153000 out of 4687104 audio features
# Processed 154000 out of 4687104 audio features
# Processed 155000 out of 4687104 audio features
# Processed 156000 out of 4687104 audio features
# Processed 157000 out of 4687104 audio features
# Processed 158000 out of 4687104 audio features
# Processed 159000 out of 4687104 audio features
# Processed 160000 out of 4687104 audio features
# Processed 161000 out of 4687104 audio features
# Processed 162000 out of 4687104 audio features
# Processed 163000 out of 4687104 audio features
# Processed 164000 out of 4687104 audio features
# Processed 165000 out of 4687104 audio features
# Processed 166000 out of 4687104 audio features
# Processed 167000 out of 4687104 audio features
# Processed 168000 out of 4687104 audio features
# Processed 169000 out of 4687104 audio features
# Processed 170000 out of 4687104 audio features
# Processed 171000 out of 4687104 audio features
# Processed 172000 out of 4687104 audio features
# Processed 173000 out of 4687104 audio features
# Processed 174000 out of 4687104 audio features
# Processed 175000 out of 4687104 audio features
# Processed 176000 out of 4687104 audio features
# Processed 177000 out of 4687104 audio features
# Processed 178000 out of 4687104 audio features
# Processed 179000 out of 4687104 audio features
# Processed 180000 out of 4687104 audio features
# Processed 181000 out of 4687104 audio features
# Processed 182000 out of 4687104 audio features
# Processed 183000 out of 4687104 audio features
# Processed 184000 out of 4687104 audio features
# Processed 185000 out of 4687104 audio features
# Processed 186000 out of 4687104 audio features
# Processed 187000 out of 4687104 audio features
# Processed 188000 out of 4687104 audio features
# Processed 189000 out of 4687104 audio features
# Processed 190000 out of 4687104 audio features
# Processed 191000 out of 4687104 audio features
# Processed 192000 out of 4687104 audio features
# Processed 193000 out of 4687104 audio features
# Processed 194000 out of 4687104 audio features
# Processed 195000 out of 4687104 audio features
# Processed 196000 out of 4687104 audio features
# Processed 197000 out of 4687104 audio features
# Processed 198000 out of 4687104 audio features
# Processed 199000 out of 4687104 audio features
# Processed 200000 out of 4687104 audio features
# Processed 201000 out of 4687104 audio features
# Processed 202000 out of 4687104 audio features
# Processed 203000 out of 4687104 audio features
# Processed 204000 out of 4687104 audio features
# Processed 205000 out of 4687104 audio features
# Processed 206000 out of 4687104 audio features
# Processed 207000 out of 4687104 audio features
# Processed 208000 out of 4687104 audio features
# Processed 209000 out of 4687104 audio features
# Processed 210000 out of 4687104 audio features
# Processed 211000 out of 4687104 audio features
# Processed 212000 out of 4687104 audio features
# Processed 213000 out of 4687104 audio features
# Processed 214000 out of 4687104 audio features
# Processed 215000 out of 4687104 audio features
# Processed 216000 out of 4687104 audio features
# Processed 217000 out of 4687104 audio features
# Processed 218000 out of 4687104 audio features
# Processed 219000 out of 4687104 audio features
# Processed 220000 out of 4687104 audio features
# Processed 221000 out of 4687104 audio features
# Processed 222000 out of 4687104 audio features
# Processed 223000 out of 4687104 audio features
# Processed 224000 out of 4687104 audio features
# Processed 225000 out of 4687104 audio features
# Processed 226000 out of 4687104 audio features
# Processed 227000 out of 4687104 audio features
# Processed 228000 out of 4687104 audio features
# Processed 229000 out of 4687104 audio features
# Processed 230000 out of 4687104 audio features
# Processed 231000 out of 4687104 audio features
# Processed 232000 out of 4687104 audio features
# Processed 233000 out of 4687104 audio features
# Processed 234000 out of 4687104 audio features
# Processed 235000 out of 4687104 audio features
# Processed 236000 out of 4687104 audio features
# Processed 237000 out of 4687104 audio features
# Processed 238000 out of 4687104 audio features
# Processed 239000 out of 4687104 audio features
# Processed 240000 out of 4687104 audio features
# Processed 241000 out of 4687104 audio features
# Processed 242000 out of 4687104 audio features
# Processed 243000 out of 4687104 audio features
# Processed 244000 out of 4687104 audio features
# Processed 245000 out of 4687104 audio features
# Processed 246000 out of 4687104 audio features
# Processed 247000 out of 4687104 audio features
# Processed 248000 out of 4687104 audio features
# Processed 249000 out of 4687104 audio features
# Processed 250000 out of 4687104 audio features
# Processed 251000 out of 4687104 audio features
# Processed 252000 out of 4687104 audio features
# Processed 253000 out of 4687104 audio features
# Processed 254000 out of 4687104 audio features
# Processed 255000 out of 4687104 audio features
# Processed 256000 out of 4687104 audio features
# Processed 257000 out of 4687104 audio features
# Processed 258000 out of 4687104 audio features
# Processed 259000 out of 4687104 audio features
# Processed 260000 out of 4687104 audio features
# Processed 261000 out of 4687104 audio features
# Processed 262000 out of 4687104 audio features
# Processed 263000 out of 4687104 audio features
# Processed 264000 out of 4687104 audio features
# Processed 265000 out of 4687104 audio features
# Processed 266000 out of 4687104 audio features
# Processed 267000 out of 4687104 audio features
# Processed 268000 out of 4687104 audio features
# Processed 269000 out of 4687104 audio features
# Processed 270000 out of 4687104 audio features
# Processed 271000 out of 4687104 audio features
# Processed 272000 out of 4687104 audio features
# Processed 273000 out of 4687104 audio features
# Processed 274000 out of 4687104 audio features
# Processed 275000 out of 4687104 audio features
# Processed 276000 out of 4687104 audio features
# Processed 277000 out of 4687104 audio features
# Processed 278000 out of 4687104 audio features
# Processed 279000 out of 4687104 audio features
# Processed 280000 out of 4687104 audio features
# Processed 281000 out of 4687104 audio features
# Processed 282000 out of 4687104 audio features
# Processed 283000 out of 4687104 audio features
# Processed 284000 out of 4687104 audio features
# Processed 285000 out of 4687104 audio features
# Processed 286000 out of 4687104 audio features
# Processed 287000 out of 4687104 audio features
# Processed 288000 out of 4687104 audio features
# Processed 289000 out of 4687104 audio features
# Processed 290000 out of 4687104 audio features
# Processed 291000 out of 4687104 audio features
# Processed 292000 out of 4687104 audio features
# Processed 293000 out of 4687104 audio features
# Processed 294000 out of 4687104 audio features
# Processed 295000 out of 4687104 audio features
# Processed 296000 out of 4687104 audio features
# Processed 297000 out of 4687104 audio features
# Processed 298000 out of 4687104 audio features
# Processed 299000 out of 4687104 audio features
# Processed 300000 out of 4687104 audio features
# Processed 301000 out of 4687104 audio features
# Processed 302000 out of 4687104 audio features
# Processed 303000 out of 4687104 audio features
# Processed 304000 out of 4687104 audio features
# Processed 305000 out of 4687104 audio features
# Processed 306000 out of 4687104 audio features
# Processed 307000 out of 4687104 audio features
# Processed 308000 out of 4687104 audio features
# Processed 309000 out of 4687104 audio features
# Processed 310000 out of 4687104 audio features
# Processed 311000 out of 4687104 audio features
# Processed 312000 out of 4687104 audio features
# Processed 313000 out of 4687104 audio features
# Processed 314000 out of 4687104 audio features
# Processed 315000 out of 4687104 audio features
# Processed 316000 out of 4687104 audio features
# Processed 317000 out of 4687104 audio features
# Processed 318000 out of 4687104 audio features
# Processed 319000 out of 4687104 audio features
# Processed 320000 out of 4687104 audio features
# Processed 321000 out of 4687104 audio features
# Processed 322000 out of 4687104 audio features
# Processed 323000 out of 4687104 audio features
# Processed 324000 out of 4687104 audio features
# Processed 325000 out of 4687104 audio features
# Processed 326000 out of 4687104 audio features
# Processed 327000 out of 4687104 audio features
# Processed 328000 out of 4687104 audio features
# Processed 329000 out of 4687104 audio features
# Processed 330000 out of 4687104 audio features
# Processed 331000 out of 4687104 audio features
# Processed 332000 out of 4687104 audio features
# Processed 333000 out of 4687104 audio features
# Processed 334000 out of 4687104 audio features
# Processed 335000 out of 4687104 audio features
# Processed 336000 out of 4687104 audio features
# Processed 337000 out of 4687104 audio features
# Processed 338000 out of 4687104 audio features
# Processed 339000 out of 4687104 audio features
# Processed 340000 out of 4687104 audio features
# Processed 341000 out of 4687104 audio features
# Processed 342000 out of 4687104 audio features
# Processed 343000 out of 4687104 audio features
# Processed 344000 out of 4687104 audio features
# Processed 345000 out of 4687104 audio features
# Processed 346000 out of 4687104 audio features
# Processed 347000 out of 4687104 audio features
# Processed 348000 out of 4687104 audio features
# Processed 349000 out of 4687104 audio features
# Processed 350000 out of 4687104 audio features
# Processed 351000 out of 4687104 audio features
# Processed 352000 out of 4687104 audio features
# Processed 353000 out of 4687104 audio features
# Processed 354000 out of 4687104 audio features
# Processed 355000 out of 4687104 audio features
# Processed 356000 out of 4687104 audio features
# Processed 357000 out of 4687104 audio features
# Processed 358000 out of 4687104 audio features
# Processed 359000 out of 4687104 audio features
# Processed 360000 out of 4687104 audio features
# Processed 361000 out of 4687104 audio features
# Processed 362000 out of 4687104 audio features
# Processed 363000 out of 4687104 audio features
# Processed 364000 out of 4687104 audio features
# Processed 365000 out of 4687104 audio features
# Processed 366000 out of 4687104 audio features
# Processed 367000 out of 4687104 audio features
# Processed 368000 out of 4687104 audio features
# Processed 369000 out of 4687104 audio features
# Processed 370000 out of 4687104 audio features
# Processed 371000 out of 4687104 audio features
# Processed 372000 out of 4687104 audio features
# Processed 373000 out of 4687104 audio features
# Processed 374000 out of 4687104 audio features
# Processed 375000 out of 4687104 audio features
# Processed 376000 out of 4687104 audio features
# Processed 377000 out of 4687104 audio features
# Processed 378000 out of 4687104 audio features
# Processed 379000 out of 4687104 audio features
# Processed 380000 out of 4687104 audio features
# Processed 381000 out of 4687104 audio features
# Processed 382000 out of 4687104 audio features
# Processed 383000 out of 4687104 audio features
# Processed 384000 out of 4687104 audio features
# Processed 385000 out of 4687104 audio features
# Processed 386000 out of 4687104 audio features
# Processed 387000 out of 4687104 audio features
# Processed 388000 out of 4687104 audio features
# Processed 389000 out of 4687104 audio features
# Processed 390000 out of 4687104 audio features
# Processed 391000 out of 4687104 audio features
# Processed 392000 out of 4687104 audio features
# Processed 393000 out of 4687104 audio features
# Processed 394000 out of 4687104 audio features
# Processed 395000 out of 4687104 audio features
# Processed 396000 out of 4687104 audio features
# Processed 397000 out of 4687104 audio features
# Processed 398000 out of 4687104 audio features
# Processed 399000 out of 4687104 audio features
# Processed 400000 out of 4687104 audio features
# Processed 401000 out of 4687104 audio features
# Processed 402000 out of 4687104 audio features
# Processed 403000 out of 4687104 audio features
# Processed 404000 out of 4687104 audio features
# Processed 405000 out of 4687104 audio features
# Processed 406000 out of 4687104 audio features
# Processed 407000 out of 4687104 audio features
# Processed 408000 out of 4687104 audio features
# Processed 409000 out of 4687104 audio features
# Processed 410000 out of 4687104 audio features
# Processed 411000 out of 4687104 audio features
# Processed 412000 out of 4687104 audio features
# Processed 413000 out of 4687104 audio features
# Processed 414000 out of 4687104 audio features
# Processed 415000 out of 4687104 audio features
# Processed 416000 out of 4687104 audio features
# Processed 417000 out of 4687104 audio features
# Processed 418000 out of 4687104 audio features
# Processed 419000 out of 4687104 audio features
# Processed 420000 out of 4687104 audio features
# Processed 421000 out of 4687104 audio features
# Processed 422000 out of 4687104 audio features
# Processed 423000 out of 4687104 audio features
# Processed 424000 out of 4687104 audio features
# Processed 425000 out of 4687104 audio features
# Processed 426000 out of 4687104 audio features
# Processed 427000 out of 4687104 audio features
# Processed 428000 out of 4687104 audio features
# Processed 429000 out of 4687104 audio features
# Processed 430000 out of 4687104 audio features
# Processed 431000 out of 4687104 audio features
# Processed 432000 out of 4687104 audio features
# Processed 433000 out of 4687104 audio features
# Processed 434000 out of 4687104 audio features
# Processed 435000 out of 4687104 audio features
# Processed 436000 out of 4687104 audio features
# Processed 437000 out of 4687104 audio features
# Processed 438000 out of 4687104 audio features
# Processed 439000 out of 4687104 audio features
# Processed 440000 out of 4687104 audio features
# Processed 441000 out of 4687104 audio features
# Processed 442000 out of 4687104 audio features
# Processed 443000 out of 4687104 audio features
# Processed 444000 out of 4687104 audio features
# Processed 445000 out of 4687104 audio features
# Processed 446000 out of 4687104 audio features
# Processed 447000 out of 4687104 audio features
# Processed 448000 out of 4687104 audio features
# Processed 449000 out of 4687104 audio features
# Processed 450000 out of 4687104 audio features
# Processed 451000 out of 4687104 audio features
# Processed 452000 out of 4687104 audio features
# Processed 453000 out of 4687104 audio features
# Processed 454000 out of 4687104 audio features
# Processed 455000 out of 4687104 audio features
# Processed 456000 out of 4687104 audio features
# Processed 457000 out of 4687104 audio features
# Processed 458000 out of 4687104 audio features
# Processed 459000 out of 4687104 audio features
# Processed 460000 out of 4687104 audio features
# Processed 461000 out of 4687104 audio features
# Processed 462000 out of 4687104 audio features
# Processed 463000 out of 4687104 audio features
# Processed 464000 out of 4687104 audio features
# Processed 465000 out of 4687104 audio features
# Processed 466000 out of 4687104 audio features
# Processed 467000 out of 4687104 audio features
# Processed 468000 out of 4687104 audio features
# Processed 469000 out of 4687104 audio features
# Processed 470000 out of 4687104 audio features
# Processed 471000 out of 4687104 audio features
# Processed 472000 out of 4687104 audio features
# Processed 473000 out of 4687104 audio features
# Processed 474000 out of 4687104 audio features
# Processed 475000 out of 4687104 audio features
# Processed 476000 out of 4687104 audio features
# Processed 477000 out of 4687104 audio features
# Processed 478000 out of 4687104 audio features
# Processed 479000 out of 4687104 audio features
# Processed 480000 out of 4687104 audio features
# Processed 481000 out of 4687104 audio features
# Processed 482000 out of 4687104 audio features
# Processed 483000 out of 4687104 audio features
# Processed 484000 out of 4687104 audio features
# Processed 485000 out of 4687104 audio features
# Processed 486000 out of 4687104 audio features
# Processed 487000 out of 4687104 audio features
# Processed 488000 out of 4687104 audio features
# Processed 489000 out of 4687104 audio features
# Processed 490000 out of 4687104 audio features
# Processed 491000 out of 4687104 audio features
# Processed 492000 out of 4687104 audio features
# Processed 493000 out of 4687104 audio features
# Processed 494000 out of 4687104 audio features
# Processed 495000 out of 4687104 audio features
# Processed 496000 out of 4687104 audio features
# Processed 497000 out of 4687104 audio features
# Processed 498000 out of 4687104 audio features
# Processed 499000 out of 4687104 audio features
# Processed 500000 out of 4687104 audio features
# Processed 501000 out of 4687104 audio features
# Processed 502000 out of 4687104 audio features
# Processed 503000 out of 4687104 audio features
# Processed 504000 out of 4687104 audio features
# Processed 505000 out of 4687104 audio features
# Processed 506000 out of 4687104 audio features
# Processed 507000 out of 4687104 audio features
# Processed 508000 out of 4687104 audio features
# Processed 509000 out of 4687104 audio features
# Processed 510000 out of 4687104 audio features
# Processed 511000 out of 4687104 audio features
# Processed 512000 out of 4687104 audio features
# Processed 513000 out of 4687104 audio features
# Processed 514000 out of 4687104 audio features
# Processed 515000 out of 4687104 audio features
# Processed 516000 out of 4687104 audio features
# Processed 517000 out of 4687104 audio features
# Processed 518000 out of 4687104 audio features
# Processed 519000 out of 4687104 audio features
# Processed 520000 out of 4687104 audio features
# Processed 521000 out of 4687104 audio features
# Processed 522000 out of 4687104 audio features
# Processed 523000 out of 4687104 audio features
# Processed 524000 out of 4687104 audio features
# Processed 525000 out of 4687104 audio features
# Processed 526000 out of 4687104 audio features
# Processed 527000 out of 4687104 audio features
# Processed 528000 out of 4687104 audio features
# Processed 529000 out of 4687104 audio features
# Processed 530000 out of 4687104 audio features
# Processed 531000 out of 4687104 audio features
# Processed 532000 out of 4687104 audio features
# Processed 533000 out of 4687104 audio features
# Processed 534000 out of 4687104 audio features
# Processed 535000 out of 4687104 audio features
# Processed 536000 out of 4687104 audio features
# Processed 537000 out of 4687104 audio features
# Processed 538000 out of 4687104 audio features
# Processed 539000 out of 4687104 audio features
# Processed 540000 out of 4687104 audio features
# Processed 541000 out of 4687104 audio features
# Processed 542000 out of 4687104 audio features
# Processed 543000 out of 4687104 audio features
# Processed 544000 out of 4687104 audio features
# Processed 545000 out of 4687104 audio features
# Processed 546000 out of 4687104 audio features
# Processed 547000 out of 4687104 audio features
# Processed 548000 out of 4687104 audio features
# Processed 549000 out of 4687104 audio features
# Processed 550000 out of 4687104 audio features
# Processed 551000 out of 4687104 audio features
# Processed 552000 out of 4687104 audio features
# Processed 553000 out of 4687104 audio features
# Processed 554000 out of 4687104 audio features
# Processed 555000 out of 4687104 audio features
# Processed 556000 out of 4687104 audio features
# Processed 557000 out of 4687104 audio features
# Processed 558000 out of 4687104 audio features
# Processed 559000 out of 4687104 audio features
# Processed 560000 out of 4687104 audio features
# Processed 561000 out of 4687104 audio features
# Processed 562000 out of 4687104 audio features
# Processed 563000 out of 4687104 audio features
# Processed 564000 out of 4687104 audio features
# Processed 565000 out of 4687104 audio features
# Processed 566000 out of 4687104 audio features
# Processed 567000 out of 4687104 audio features
# Processed 568000 out of 4687104 audio features
# Processed 569000 out of 4687104 audio features
# Processed 570000 out of 4687104 audio features
# Processed 571000 out of 4687104 audio features
# Processed 572000 out of 4687104 audio features
# Processed 573000 out of 4687104 audio features
# Processed 574000 out of 4687104 audio features
# Processed 575000 out of 4687104 audio features
# Processed 576000 out of 4687104 audio features
# Processed 577000 out of 4687104 audio features
# Processed 578000 out of 4687104 audio features
# Processed 579000 out of 4687104 audio features
# Processed 580000 out of 4687104 audio features
# Processed 581000 out of 4687104 audio features
# Processed 582000 out of 4687104 audio features
# Processed 583000 out of 4687104 audio features
# Processed 584000 out of 4687104 audio features
# Processed 585000 out of 4687104 audio features
# Processed 586000 out of 4687104 audio features
# Processed 587000 out of 4687104 audio features
# Processed 588000 out of 4687104 audio features
# Processed 589000 out of 4687104 audio features
# Processed 590000 out of 4687104 audio features
# Processed 591000 out of 4687104 audio features
# Processed 592000 out of 4687104 audio features
# Processed 593000 out of 4687104 audio features
# Processed 594000 out of 4687104 audio features
# Processed 595000 out of 4687104 audio features
# Processed 596000 out of 4687104 audio features
# Processed 597000 out of 4687104 audio features
# Processed 598000 out of 4687104 audio features
# Processed 599000 out of 4687104 audio features
# Processed 600000 out of 4687104 audio features
# Processed 601000 out of 4687104 audio features
# Processed 602000 out of 4687104 audio features
# Processed 603000 out of 4687104 audio features
# Processed 604000 out of 4687104 audio features
# Processed 605000 out of 4687104 audio features
# Processed 606000 out of 4687104 audio features
# Processed 607000 out of 4687104 audio features
# Processed 608000 out of 4687104 audio features
# Processed 609000 out of 4687104 audio features
# Processed 610000 out of 4687104 audio features
# Processed 611000 out of 4687104 audio features
# Processed 612000 out of 4687104 audio features
# Processed 613000 out of 4687104 audio features
# Processed 614000 out of 4687104 audio features
# Processed 615000 out of 4687104 audio features
# Processed 616000 out of 4687104 audio features
# Processed 617000 out of 4687104 audio features
# Processed 618000 out of 4687104 audio features
# Processed 619000 out of 4687104 audio features
# Processed 620000 out of 4687104 audio features
# Processed 621000 out of 4687104 audio features
# Processed 622000 out of 4687104 audio features
# Processed 623000 out of 4687104 audio features
# Processed 624000 out of 4687104 audio features
# Processed 625000 out of 4687104 audio features
# Processed 626000 out of 4687104 audio features
# Processed 627000 out of 4687104 audio features
# Processed 628000 out of 4687104 audio features
# Processed 629000 out of 4687104 audio features
# Processed 630000 out of 4687104 audio features
# Processed 631000 out of 4687104 audio features
# Processed 632000 out of 4687104 audio features
# Processed 633000 out of 4687104 audio features
# Processed 634000 out of 4687104 audio features
# Processed 635000 out of 4687104 audio features
# Processed 636000 out of 4687104 audio features
# Processed 637000 out of 4687104 audio features
# Processed 638000 out of 4687104 audio features
# Processed 639000 out of 4687104 audio features
# Processed 640000 out of 4687104 audio features
# Processed 641000 out of 4687104 audio features
# Processed 642000 out of 4687104 audio features
# Processed 643000 out of 4687104 audio features
# Processed 644000 out of 4687104 audio features
# Processed 645000 out of 4687104 audio features
# Processed 646000 out of 4687104 audio features
# Processed 647000 out of 4687104 audio features
# Processed 648000 out of 4687104 audio features
# Processed 649000 out of 4687104 audio features
# Processed 650000 out of 4687104 audio features
# Processed 651000 out of 4687104 audio features
# Processed 652000 out of 4687104 audio features
# Processed 653000 out of 4687104 audio features
# Processed 654000 out of 4687104 audio features
# Processed 655000 out of 4687104 audio features
# Processed 656000 out of 4687104 audio features
# Processed 657000 out of 4687104 audio features
# Processed 658000 out of 4687104 audio features
# Processed 659000 out of 4687104 audio features
# Processed 660000 out of 4687104 audio features
# Processed 661000 out of 4687104 audio features
# Processed 662000 out of 4687104 audio features
# Processed 663000 out of 4687104 audio features
# Processed 664000 out of 4687104 audio features
# Processed 665000 out of 4687104 audio features
# Processed 666000 out of 4687104 audio features
# Processed 667000 out of 4687104 audio features
# Processed 668000 out of 4687104 audio features
# Processed 669000 out of 4687104 audio features
# Processed 670000 out of 4687104 audio features
# Processed 671000 out of 4687104 audio features
# Processed 672000 out of 4687104 audio features
# Processed 673000 out of 4687104 audio features
# Processed 674000 out of 4687104 audio features
# Processed 675000 out of 4687104 audio features
# Processed 676000 out of 4687104 audio features
# Processed 677000 out of 4687104 audio features
# Processed 678000 out of 4687104 audio features
# Processed 679000 out of 4687104 audio features
# Processed 680000 out of 4687104 audio features
# Processed 681000 out of 4687104 audio features
# Processed 682000 out of 4687104 audio features
# Processed 683000 out of 4687104 audio features
# Processed 684000 out of 4687104 audio features
# Processed 685000 out of 4687104 audio features
# Processed 686000 out of 4687104 audio features
# Processed 687000 out of 4687104 audio features
# Processed 688000 out of 4687104 audio features
# Processed 689000 out of 4687104 audio features
# Processed 690000 out of 4687104 audio features
# Processed 691000 out of 4687104 audio features
# Processed 692000 out of 4687104 audio features
# Processed 693000 out of 4687104 audio features
# Processed 694000 out of 4687104 audio features
# Processed 695000 out of 4687104 audio features
# Processed 696000 out of 4687104 audio features
# Processed 697000 out of 4687104 audio features
# Processed 698000 out of 4687104 audio features
# Processed 699000 out of 4687104 audio features
# Processed 700000 out of 4687104 audio features
# Processed 701000 out of 4687104 audio features
# Processed 702000 out of 4687104 audio features
# Processed 703000 out of 4687104 audio features
# Processed 704000 out of 4687104 audio features
# Processed 705000 out of 4687104 audio features
# Processed 706000 out of 4687104 audio features
# Processed 707000 out of 4687104 audio features
# Processed 708000 out of 4687104 audio features
# Processed 709000 out of 4687104 audio features
# Processed 710000 out of 4687104 audio features
# Processed 711000 out of 4687104 audio features
# Processed 712000 out of 4687104 audio features
# Processed 713000 out of 4687104 audio features
# Processed 714000 out of 4687104 audio features
# Processed 715000 out of 4687104 audio features
# Processed 716000 out of 4687104 audio features
# Processed 717000 out of 4687104 audio features
# Processed 718000 out of 4687104 audio features
# Processed 719000 out of 4687104 audio features
# Processed 720000 out of 4687104 audio features
# Processed 721000 out of 4687104 audio features
# Processed 722000 out of 4687104 audio features
# Processed 723000 out of 4687104 audio features
# Processed 724000 out of 4687104 audio features
# Processed 725000 out of 4687104 audio features
# Processed 726000 out of 4687104 audio features
# Processed 727000 out of 4687104 audio features
# Processed 728000 out of 4687104 audio features
# Processed 729000 out of 4687104 audio features
# Processed 730000 out of 4687104 audio features
# Processed 731000 out of 4687104 audio features
# Processed 732000 out of 4687104 audio features
# Processed 733000 out of 4687104 audio features
# Processed 734000 out of 4687104 audio features
# Processed 735000 out of 4687104 audio features
# Processed 736000 out of 4687104 audio features
# Processed 737000 out of 4687104 audio features
# Processed 738000 out of 4687104 audio features
# Processed 739000 out of 4687104 audio features
# Processed 740000 out of 4687104 audio features
# Processed 741000 out of 4687104 audio features
# Processed 742000 out of 4687104 audio features
# Processed 743000 out of 4687104 audio features
# Processed 744000 out of 4687104 audio features
# Processed 745000 out of 4687104 audio features
# Processed 746000 out of 4687104 audio features
# Processed 747000 out of 4687104 audio features
# Processed 748000 out of 4687104 audio features
# Processed 749000 out of 4687104 audio features
# Processed 750000 out of 4687104 audio features
# Processed 751000 out of 4687104 audio features
# Processed 752000 out of 4687104 audio features
# Processed 753000 out of 4687104 audio features
# Processed 754000 out of 4687104 audio features
# Processed 755000 out of 4687104 audio features
# Processed 756000 out of 4687104 audio features
# Processed 757000 out of 4687104 audio features
# Processed 758000 out of 4687104 audio features
# Processed 759000 out of 4687104 audio features
# Processed 760000 out of 4687104 audio features
# Processed 761000 out of 4687104 audio features
# Processed 762000 out of 4687104 audio features
# Processed 763000 out of 4687104 audio features
# Processed 764000 out of 4687104 audio features
# Processed 765000 out of 4687104 audio features
# Processed 766000 out of 4687104 audio features
# Processed 767000 out of 4687104 audio features
# Processed 768000 out of 4687104 audio features
# Processed 769000 out of 4687104 audio features
# Processed 770000 out of 4687104 audio features
# Processed 771000 out of 4687104 audio features
# Processed 772000 out of 4687104 audio features
# Processed 773000 out of 4687104 audio features
# Processed 774000 out of 4687104 audio features
# Processed 775000 out of 4687104 audio features
# Processed 776000 out of 4687104 audio features
# Processed 777000 out of 4687104 audio features
# Processed 778000 out of 4687104 audio features
# Processed 779000 out of 4687104 audio features
# Processed 780000 out of 4687104 audio features
# Processed 781000 out of 4687104 audio features
# Processed 782000 out of 4687104 audio features
# Processed 783000 out of 4687104 audio features
# Processed 784000 out of 4687104 audio features
# Processed 785000 out of 4687104 audio features
# Processed 786000 out of 4687104 audio features
# Processed 787000 out of 4687104 audio features
# Processed 788000 out of 4687104 audio features
# Processed 789000 out of 4687104 audio features
# Processed 790000 out of 4687104 audio features
# Processed 791000 out of 4687104 audio features
# Processed 792000 out of 4687104 audio features
# Processed 793000 out of 4687104 audio features
# Processed 794000 out of 4687104 audio features
# Processed 795000 out of 4687104 audio features
# Processed 796000 out of 4687104 audio features
# Processed 797000 out of 4687104 audio features
# Processed 798000 out of 4687104 audio features
# Processed 799000 out of 4687104 audio features
# Processed 800000 out of 4687104 audio features
# Processed 801000 out of 4687104 audio features
# Processed 802000 out of 4687104 audio features
# Processed 803000 out of 4687104 audio features
# Processed 804000 out of 4687104 audio features
# Processed 805000 out of 4687104 audio features
# Processed 806000 out of 4687104 audio features
# Processed 807000 out of 4687104 audio features
# Processed 808000 out of 4687104 audio features
# Processed 809000 out of 4687104 audio features
# Processed 810000 out of 4687104 audio features
# Processed 811000 out of 4687104 audio features
# Processed 812000 out of 4687104 audio features
# Processed 813000 out of 4687104 audio features
# Processed 814000 out of 4687104 audio features
# Processed 815000 out of 4687104 audio features
# Processed 816000 out of 4687104 audio features
# Processed 817000 out of 4687104 audio features
# Processed 818000 out of 4687104 audio features
# Processed 819000 out of 4687104 audio features
# Processed 820000 out of 4687104 audio features
# Processed 821000 out of 4687104 audio features
# Processed 822000 out of 4687104 audio features
# Processed 823000 out of 4687104 audio features
# Processed 824000 out of 4687104 audio features
# Processed 825000 out of 4687104 audio features
# Processed 826000 out of 4687104 audio features
# Processed 827000 out of 4687104 audio features
# Processed 828000 out of 4687104 audio features
# Processed 829000 out of 4687104 audio features
# Processed 830000 out of 4687104 audio features
# Processed 831000 out of 4687104 audio features
# Processed 832000 out of 4687104 audio features
# Processed 833000 out of 4687104 audio features
# Processed 834000 out of 4687104 audio features
# Processed 835000 out of 4687104 audio features
# Processed 836000 out of 4687104 audio features
# Processed 837000 out of 4687104 audio features
# Processed 838000 out of 4687104 audio features
# Processed 839000 out of 4687104 audio features
# Processed 840000 out of 4687104 audio features
# Processed 841000 out of 4687104 audio features
# Processed 842000 out of 4687104 audio features
# Processed 843000 out of 4687104 audio features
# Processed 844000 out of 4687104 audio features
# Processed 845000 out of 4687104 audio features
# Processed 846000 out of 4687104 audio features
# Processed 847000 out of 4687104 audio features
# Processed 848000 out of 4687104 audio features
# Processed 849000 out of 4687104 audio features
# Processed 850000 out of 4687104 audio features
# Processed 851000 out of 4687104 audio features
# Processed 852000 out of 4687104 audio features
# Processed 853000 out of 4687104 audio features
# Processed 854000 out of 4687104 audio features
# Processed 855000 out of 4687104 audio features
# Processed 856000 out of 4687104 audio features
# Processed 857000 out of 4687104 audio features
# Processed 858000 out of 4687104 audio features
# Processed 859000 out of 4687104 audio features
# Processed 860000 out of 4687104 audio features
# Processed 861000 out of 4687104 audio features
# Processed 862000 out of 4687104 audio features
# Processed 863000 out of 4687104 audio features
# Processed 864000 out of 4687104 audio features
# Processed 865000 out of 4687104 audio features
# Processed 866000 out of 4687104 audio features
# Processed 867000 out of 4687104 audio features
# Processed 868000 out of 4687104 audio features
# Processed 869000 out of 4687104 audio features
# Processed 870000 out of 4687104 audio features
# Processed 871000 out of 4687104 audio features
# Processed 872000 out of 4687104 audio features
# Processed 873000 out of 4687104 audio features
# Processed 874000 out of 4687104 audio features
# Processed 875000 out of 4687104 audio features
# Processed 876000 out of 4687104 audio features
# Processed 877000 out of 4687104 audio features
# Processed 878000 out of 4687104 audio features
# Processed 879000 out of 4687104 audio features
# Processed 880000 out of 4687104 audio features
# Processed 881000 out of 4687104 audio features
# Processed 882000 out of 4687104 audio features
# Processed 883000 out of 4687104 audio features
# Processed 884000 out of 4687104 audio features
# Processed 885000 out of 4687104 audio features
# Processed 886000 out of 4687104 audio features
# Processed 887000 out of 4687104 audio features
# Processed 888000 out of 4687104 audio features
# Processed 889000 out of 4687104 audio features
# Processed 890000 out of 4687104 audio features
# Processed 891000 out of 4687104 audio features
# Processed 892000 out of 4687104 audio features
# Processed 893000 out of 4687104 audio features
# Processed 894000 out of 4687104 audio features
# Processed 895000 out of 4687104 audio features
# Processed 896000 out of 4687104 audio features
# Processed 897000 out of 4687104 audio features
# Processed 898000 out of 4687104 audio features
# Processed 899000 out of 4687104 audio features
# Processed 900000 out of 4687104 audio features
# Processed 901000 out of 4687104 audio features
# Processed 902000 out of 4687104 audio features
# Processed 903000 out of 4687104 audio features
# Processed 904000 out of 4687104 audio features
# Processed 905000 out of 4687104 audio features
# Processed 906000 out of 4687104 audio features
# Processed 907000 out of 4687104 audio features
# Processed 908000 out of 4687104 audio features
# Processed 909000 out of 4687104 audio features
# Processed 910000 out of 4687104 audio features
# Processed 911000 out of 4687104 audio features
# Processed 912000 out of 4687104 audio features
# Processed 913000 out of 4687104 audio features
# Processed 914000 out of 4687104 audio features
# Processed 915000 out of 4687104 audio features
# Processed 916000 out of 4687104 audio features
# Processed 917000 out of 4687104 audio features
# Processed 918000 out of 4687104 audio features
# Processed 919000 out of 4687104 audio features
# Processed 920000 out of 4687104 audio features
# Processed 921000 out of 4687104 audio features
# Processed 922000 out of 4687104 audio features
# Processed 923000 out of 4687104 audio features
# Processed 924000 out of 4687104 audio features
# Processed 925000 out of 4687104 audio features
# Processed 926000 out of 4687104 audio features
# Processed 927000 out of 4687104 audio features
# Processed 928000 out of 4687104 audio features
# Processed 929000 out of 4687104 audio features
# Processed 930000 out of 4687104 audio features
# Processed 931000 out of 4687104 audio features
# Processed 932000 out of 4687104 audio features
# Processed 933000 out of 4687104 audio features
# Processed 934000 out of 4687104 audio features
# Processed 935000 out of 4687104 audio features
# Processed 936000 out of 4687104 audio features
# Processed 937000 out of 4687104 audio features
# Processed 938000 out of 4687104 audio features
# Processed 939000 out of 4687104 audio features
# Processed 940000 out of 4687104 audio features
# Processed 941000 out of 4687104 audio features
# Processed 942000 out of 4687104 audio features
# Processed 943000 out of 4687104 audio features
# Processed 944000 out of 4687104 audio features
# Processed 945000 out of 4687104 audio features
# Processed 946000 out of 4687104 audio features
# Processed 947000 out of 4687104 audio features
# Processed 948000 out of 4687104 audio features
# Processed 949000 out of 4687104 audio features
# Processed 950000 out of 4687104 audio features
# Processed 951000 out of 4687104 audio features
# Processed 952000 out of 4687104 audio features
# Processed 953000 out of 4687104 audio features
# Processed 954000 out of 4687104 audio features
# Processed 955000 out of 4687104 audio features
# Processed 956000 out of 4687104 audio features
# Processed 957000 out of 4687104 audio features
# Processed 958000 out of 4687104 audio features
# Processed 959000 out of 4687104 audio features
# Processed 960000 out of 4687104 audio features
# Processed 961000 out of 4687104 audio features
# Processed 962000 out of 4687104 audio features
# Processed 963000 out of 4687104 audio features
# Processed 964000 out of 4687104 audio features
# Processed 965000 out of 4687104 audio features
# Processed 966000 out of 4687104 audio features
# Processed 967000 out of 4687104 audio features
# Processed 968000 out of 4687104 audio features
# Processed 969000 out of 4687104 audio features
# Processed 970000 out of 4687104 audio features
# Processed 971000 out of 4687104 audio features
# Processed 972000 out of 4687104 audio features
# Processed 973000 out of 4687104 audio features
# Processed 974000 out of 4687104 audio features
# Processed 975000 out of 4687104 audio features
# Processed 976000 out of 4687104 audio features
# Processed 977000 out of 4687104 audio features
# Processed 978000 out of 4687104 audio features
# Processed 979000 out of 4687104 audio features
# Processed 980000 out of 4687104 audio features
# Processed 981000 out of 4687104 audio features
# Processed 982000 out of 4687104 audio features
# Processed 983000 out of 4687104 audio features
# Processed 984000 out of 4687104 audio features
# Processed 985000 out of 4687104 audio features
# Processed 986000 out of 4687104 audio features
# Processed 987000 out of 4687104 audio features
# Processed 988000 out of 4687104 audio features
# Processed 989000 out of 4687104 audio features
# Processed 990000 out of 4687104 audio features
# Processed 991000 out of 4687104 audio features
# Processed 992000 out of 4687104 audio features
# Processed 993000 out of 4687104 audio features
# Processed 994000 out of 4687104 audio features
# Processed 995000 out of 4687104 audio features
# Processed 996000 out of 4687104 audio features
# Processed 997000 out of 4687104 audio features
# Processed 998000 out of 4687104 audio features
# Processed 999000 out of 4687104 audio features
# Processed 1000000 out of 4687104 audio features
# Processed 1001000 out of 4687104 audio features
# Processed 1002000 out of 4687104 audio features
# Processed 1003000 out of 4687104 audio features
# Processed 1004000 out of 4687104 audio features
# Processed 1005000 out of 4687104 audio features
# Processed 1006000 out of 4687104 audio features
# Processed 1007000 out of 4687104 audio features
# Processed 1008000 out of 4687104 audio features
# Processed 1009000 out of 4687104 audio features
# Processed 1010000 out of 4687104 audio features
# Processed 1011000 out of 4687104 audio features
# Processed 1012000 out of 4687104 audio features
# Processed 1013000 out of 4687104 audio features
# Processed 1014000 out of 4687104 audio features
# Processed 1015000 out of 4687104 audio features
# Processed 1016000 out of 4687104 audio features
# Processed 1017000 out of 4687104 audio features
# Processed 1018000 out of 4687104 audio features
# Processed 1019000 out of 4687104 audio features
# Processed 1020000 out of 4687104 audio features
# Processed 1021000 out of 4687104 audio features
# Processed 1022000 out of 4687104 audio features
# ...
# Processed 4358000 out of 4687104 audio features
# Processed 4359000 out of 4687104 audio features
# Processed 4360000 out of 4687104 audio features
# Processed 4361000 out of 4687104 audio features
# Processed 4362000 out of 4687104 audio features
# Processed 4363000 out of 4687104 audio features
# Processed 4364000 out of 4687104 audio features
# Processed 4365000 out of 4687104 audio features
# Processed 4366000 out of 4687104 audio features
# Processed 4367000 out of 4687104 audio features
# Processed 4368000 out of 4687104 audio features
# Processed 4369000 out of 4687104 audio features
# Processed 4370000 out of 4687104 audio features
# Processed 4371000 out of 4687104 audio features
# Processed 4372000 out of 4687104 audio features
# Processed 4373000 out of 4687104 audio features
# Processed 4374000 out of 4687104 audio features
# Processed 4375000 out of 4687104 audio features
# Processed 4376000 out of 4687104 audio features
# Processed 4377000 out of 4687104 audio features
# Processed 4378000 out of 4687104 audio features
# Processed 4379000 out of 4687104 audio features
# Processed 4380000 out of 4687104 audio features
# Processed 4381000 out of 4687104 audio features
# Processed 4382000 out of 4687104 audio features
# Processed 4383000 out of 4687104 audio features
# Processed 4384000 out of 4687104 audio features
# Processed 4385000 out of 4687104 audio features
# Processed 4386000 out of 4687104 audio features
# Processed 4387000 out of 4687104 audio features
# Processed 4388000 out of 4687104 audio features
# Processed 4389000 out of 4687104 audio features
# Processed 4390000 out of 4687104 audio features
# Processed 4391000 out of 4687104 audio features
# Processed 4392000 out of 4687104 audio features
# Processed 4393000 out of 4687104 audio features
# Processed 4394000 out of 4687104 audio features
# Processed 4395000 out of 4687104 audio features
# Processed 4396000 out of 4687104 audio features
# Processed 4397000 out of 4687104 audio features
# Processed 4398000 out of 4687104 audio features
# Processed 4399000 out of 4687104 audio features
# Processed 4400000 out of 4687104 audio features
# Processed 4401000 out of 4687104 audio features
# Processed 4402000 out of 4687104 audio features
# Processed 4403000 out of 4687104 audio features
# Processed 4404000 out of 4687104 audio features
# Processed 4405000 out of 4687104 audio features
# Processed 4406000 out of 4687104 audio features
# Processed 4407000 out of 4687104 audio features
# Processed 4408000 out of 4687104 audio features
# Processed 4409000 out of 4687104 audio features
# Processed 4410000 out of 4687104 audio features
# Processed 4411000 out of 4687104 audio features
# Processed 4412000 out of 4687104 audio features
# Processed 4413000 out of 4687104 audio features
# Processed 4414000 out of 4687104 audio features
# Processed 4415000 out of 4687104 audio features
# Processed 4416000 out of 4687104 audio features
# Processed 4417000 out of 4687104 audio features
# Processed 4418000 out of 4687104 audio features
# Processed 4419000 out of 4687104 audio features
# Processed 4420000 out of 4687104 audio features
# Processed 4421000 out of 4687104 audio features
# Processed 4422000 out of 4687104 audio features
# Processed 4423000 out of 4687104 audio features
# Processed 4424000 out of 4687104 audio features
# Processed 4425000 out of 4687104 audio features
# Processed 4426000 out of 4687104 audio features
# Processed 4427000 out of 4687104 audio features
# Processed 4428000 out of 4687104 audio features
# Processed 4429000 out of 4687104 audio features
# Processed 4430000 out of 4687104 audio features
# Processed 4431000 out of 4687104 audio features
# Processed 4432000 out of 4687104 audio features
# Processed 4433000 out of 4687104 audio features
# Processed 4434000 out of 4687104 audio features
# Processed 4435000 out of 4687104 audio features
# Processed 4436000 out of 4687104 audio features
# Processed 4437000 out of 4687104 audio features
# Processed 4438000 out of 4687104 audio features
# Processed 4439000 out of 4687104 audio features
# Processed 4440000 out of 4687104 audio features
# Processed 4441000 out of 4687104 audio features
# Processed 4442000 out of 4687104 audio features
# Processed 4443000 out of 4687104 audio features
# Processed 4444000 out of 4687104 audio features
# Processed 4445000 out of 4687104 audio features
# Processed 4446000 out of 4687104 audio features
# Processed 4447000 out of 4687104 audio features
# Processed 4448000 out of 4687104 audio features
# Processed 4449000 out of 4687104 audio features
# Processed 4450000 out of 4687104 audio features
# Processed 4451000 out of 4687104 audio features
# Processed 4452000 out of 4687104 audio features
# Processed 4453000 out of 4687104 audio features
# Processed 4454000 out of 4687104 audio features
# Processed 4455000 out of 4687104 audio features
# Processed 4456000 out of 4687104 audio features
# Processed 4457000 out of 4687104 audio features
# Processed 4458000 out of 4687104 audio features
# Processed 4459000 out of 4687104 audio features
# Processed 4460000 out of 4687104 audio features
# Processed 4461000 out of 4687104 audio features
# Processed 4462000 out of 4687104 audio features
# Processed 4463000 out of 4687104 audio features
# Processed 4464000 out of 4687104 audio features
# Processed 4465000 out of 4687104 audio features
# Processed 4466000 out of 4687104 audio features
# Processed 4467000 out of 4687104 audio features
# Processed 4468000 out of 4687104 audio features
# Processed 4469000 out of 4687104 audio features
# Processed 4470000 out of 4687104 audio features
# Processed 4471000 out of 4687104 audio features
# Processed 4472000 out of 4687104 audio features
# Processed 4473000 out of 4687104 audio features
# Processed 4474000 out of 4687104 audio features
# Processed 4475000 out of 4687104 audio features
# Processed 4476000 out of 4687104 audio features
# Processed 4477000 out of 4687104 audio features
# Processed 4478000 out of 4687104 audio features
# Processed 4479000 out of 4687104 audio features
# Processed 4480000 out of 4687104 audio features
# Processed 4481000 out of 4687104 audio features
# Processed 4482000 out of 4687104 audio features
# Processed 4483000 out of 4687104 audio features
# Processed 4484000 out of 4687104 audio features
# Processed 4485000 out of 4687104 audio features
# Processed 4486000 out of 4687104 audio features
# Processed 4487000 out of 4687104 audio features
# Processed 4488000 out of 4687104 audio features
# Processed 4489000 out of 4687104 audio features
# Processed 4490000 out of 4687104 audio features
# Processed 4491000 out of 4687104 audio features
# Processed 4492000 out of 4687104 audio features
# Processed 4493000 out of 4687104 audio features
# Processed 4494000 out of 4687104 audio features
# Processed 4495000 out of 4687104 audio features
# Processed 4496000 out of 4687104 audio features
# Processed 4497000 out of 4687104 audio features
# Processed 4498000 out of 4687104 audio features
# Processed 4499000 out of 4687104 audio features
# Processed 4500000 out of 4687104 audio features
# Processed 4501000 out of 4687104 audio features
# Processed 4502000 out of 4687104 audio features
# Processed 4503000 out of 4687104 audio features
# Processed 4504000 out of 4687104 audio features
# Processed 4505000 out of 4687104 audio features
# Processed 4506000 out of 4687104 audio features
# Processed 4507000 out of 4687104 audio features
# Processed 4508000 out of 4687104 audio features
# Processed 4509000 out of 4687104 audio features
# Processed 4510000 out of 4687104 audio features
# Processed 4511000 out of 4687104 audio features
# Processed 4512000 out of 4687104 audio features
# Processed 4513000 out of 4687104 audio features
# Processed 4514000 out of 4687104 audio features
# Processed 4515000 out of 4687104 audio features
# Processed 4516000 out of 4687104 audio features
# Processed 4517000 out of 4687104 audio features
# Processed 4518000 out of 4687104 audio features
# Processed 4519000 out of 4687104 audio features
# Processed 4520000 out of 4687104 audio features
# Processed 4521000 out of 4687104 audio features
# Processed 4522000 out of 4687104 audio features
# Processed 4523000 out of 4687104 audio features
# Processed 4524000 out of 4687104 audio features
# Processed 4525000 out of 4687104 audio features
# Processed 4526000 out of 4687104 audio features
# Processed 4527000 out of 4687104 audio features
# Processed 4528000 out of 4687104 audio features
# Processed 4529000 out of 4687104 audio features
# Processed 4530000 out of 4687104 audio features
# Processed 4531000 out of 4687104 audio features
# Processed 4532000 out of 4687104 audio features
# Processed 4533000 out of 4687104 audio features
# Processed 4534000 out of 4687104 audio features
# Processed 4535000 out of 4687104 audio features
# Processed 4536000 out of 4687104 audio features
# Processed 4537000 out of 4687104 audio features
# Processed 4538000 out of 4687104 audio features
# Processed 4539000 out of 4687104 audio features
# Processed 4540000 out of 4687104 audio features
# Processed 4541000 out of 4687104 audio features
# Processed 4542000 out of 4687104 audio features
# Processed 4543000 out of 4687104 audio features
# Processed 4544000 out of 4687104 audio features
# Processed 4545000 out of 4687104 audio features
# Processed 4546000 out of 4687104 audio features
# Processed 4547000 out of 4687104 audio features
# Processed 4548000 out of 4687104 audio features
# Processed 4549000 out of 4687104 audio features
# Processed 4550000 out of 4687104 audio features
# Processed 4551000 out of 4687104 audio features
# Processed 4552000 out of 4687104 audio features
# Processed 4553000 out of 4687104 audio features
# Processed 4554000 out of 4687104 audio features
# Processed 4555000 out of 4687104 audio features
# Processed 4556000 out of 4687104 audio features
# Processed 4557000 out of 4687104 audio features
# Processed 4558000 out of 4687104 audio features
# Processed 4559000 out of 4687104 audio features
# Processed 4560000 out of 4687104 audio features
# Processed 4561000 out of 4687104 audio features
# Processed 4562000 out of 4687104 audio features
# Processed 4563000 out of 4687104 audio features
# Processed 4564000 out of 4687104 audio features
# Processed 4565000 out of 4687104 audio features
# Processed 4566000 out of 4687104 audio features
# Processed 4567000 out of 4687104 audio features
# Processed 4568000 out of 4687104 audio features
# Processed 4569000 out of 4687104 audio features
# Processed 4570000 out of 4687104 audio features
# Processed 4571000 out of 4687104 audio features
# Processed 4572000 out of 4687104 audio features
# Processed 4573000 out of 4687104 audio features
# Processed 4574000 out of 4687104 audio features
# Processed 4575000 out of 4687104 audio features
# Processed 4576000 out of 4687104 audio features
# Processed 4577000 out of 4687104 audio features
# Processed 4578000 out of 4687104 audio features
# Processed 4579000 out of 4687104 audio features
# Processed 4580000 out of 4687104 audio features
# Processed 4581000 out of 4687104 audio features
# Processed 4582000 out of 4687104 audio features
# Processed 4583000 out of 4687104 audio features
# Processed 4584000 out of 4687104 audio features
# Processed 4585000 out of 4687104 audio features
# Processed 4586000 out of 4687104 audio features
# Processed 4587000 out of 4687104 audio features
# Processed 4588000 out of 4687104 audio features
# Processed 4589000 out of 4687104 audio features
# Processed 4590000 out of 4687104 audio features
# Processed 4591000 out of 4687104 audio features
# Processed 4592000 out of 4687104 audio features
# Processed 4593000 out of 4687104 audio features
# Processed 4594000 out of 4687104 audio features
# Processed 4595000 out of 4687104 audio features
# Processed 4596000 out of 4687104 audio features
# Processed 4597000 out of 4687104 audio features
# Processed 4598000 out of 4687104 audio features
# Processed 4599000 out of 4687104 audio features
# Processed 4600000 out of 4687104 audio features
# Processed 4601000 out of 4687104 audio features
# Processed 4602000 out of 4687104 audio features
# Processed 4603000 out of 4687104 audio features
# Processed 4604000 out of 4687104 audio features
# Processed 4605000 out of 4687104 audio features
# Processed 4606000 out of 4687104 audio features
# Processed 4607000 out of 4687104 audio features
# Processed 4608000 out of 4687104 audio features
# Processed 4609000 out of 4687104 audio features
# Processed 4610000 out of 4687104 audio features
# Processed 4611000 out of 4687104 audio features
# Processed 4612000 out of 4687104 audio features
# Processed 4613000 out of 4687104 audio features
# Processed 4614000 out of 4687104 audio features
# Processed 4615000 out of 4687104 audio features
# Processed 4616000 out of 4687104 audio features
# Processed 4617000 out of 4687104 audio features
# Processed 4618000 out of 4687104 audio features
# Processed 4619000 out of 4687104 audio features
# Processed 4620000 out of 4687104 audio features
# Processed 4621000 out of 4687104 audio features
# Processed 4622000 out of 4687104 audio features
# Processed 4623000 out of 4687104 audio features
# Processed 4624000 out of 4687104 audio features
# Processed 4625000 out of 4687104 audio features
# Processed 4626000 out of 4687104 audio features
# Processed 4627000 out of 4687104 audio features
# Processed 4628000 out of 4687104 audio features
# Processed 4629000 out of 4687104 audio features
# Processed 4630000 out of 4687104 audio features
# Processed 4631000 out of 4687104 audio features
# Processed 4632000 out of 4687104 audio features
# Processed 4633000 out of 4687104 audio features
# Processed 4634000 out of 4687104 audio features
# Processed 4635000 out of 4687104 audio features
# Processed 4636000 out of 4687104 audio features
# Processed 4637000 out of 4687104 audio features
# Processed 4638000 out of 4687104 audio features
# Processed 4639000 out of 4687104 audio features
# Processed 4640000 out of 4687104 audio features
# Processed 4641000 out of 4687104 audio features
# Processed 4642000 out of 4687104 audio features
# Processed 4643000 out of 4687104 audio features
# Processed 4644000 out of 4687104 audio features
# Processed 4645000 out of 4687104 audio features
# Processed 4646000 out of 4687104 audio features
# Processed 4647000 out of 4687104 audio features
# Processed 4648000 out of 4687104 audio features
# Processed 4649000 out of 4687104 audio features
# Processed 4650000 out of 4687104 audio features
# Processed 4651000 out of 4687104 audio features
# Processed 4652000 out of 4687104 audio features
# Processed 4653000 out of 4687104 audio features
# Processed 4654000 out of 4687104 audio features
# Processed 4655000 out of 4687104 audio features
# Processed 4656000 out of 4687104 audio features
# Processed 4657000 out of 4687104 audio features
# Processed 4658000 out of 4687104 audio features
# Processed 4659000 out of 4687104 audio features
# Processed 4660000 out of 4687104 audio features
# Processed 4661000 out of 4687104 audio features
# Processed 4662000 out of 4687104 audio features
# Processed 4663000 out of 4687104 audio features
# Processed 4664000 out of 4687104 audio features
# Processed 4665000 out of 4687104 audio features
# Processed 4666000 out of 4687104 audio features
# Processed 4667000 out of 4687104 audio features
# Processed 4668000 out of 4687104 audio features
# Processed 4669000 out of 4687104 audio features
# Processed 4670000 out of 4687104 audio features
# Processed 4671000 out of 4687104 audio features
# Processed 4672000 out of 4687104 audio features
# Processed 4673000 out of 4687104 audio features
# Processed 4674000 out of 4687104 audio features
# Processed 4675000 out of 4687104 audio features
# Processed 4676000 out of 4687104 audio features
# Processed 4677000 out of 4687104 audio features
# Processed 4678000 out of 4687104 audio features
# Processed 4679000 out of 4687104 audio features
# Processed 4680000 out of 4687104 audio features
# Processed 4681000 out of 4687104 audio features
# Processed 4682000 out of 4687104 audio features
# Processed 4683000 out of 4687104 audio features
# Processed 4684000 out of 4687104 audio features
# Processed 4685000 out of 4687104 audio features
# Processed 4686000 out of 4687104 audio features
# Processed 4687000 out of 4687104 audio features
# Processed 4687104 out of 4687104 audio features
# Audio features imported successfully
# All data imported successfully!

# %%
def import_artist_tracks(engine):
    """Import artist-track relationships with parameter binding"""
    try:
        print("Importing artist-track relationships...")
        df = pd.read_csv('sp_artist_track.csv')
        df = clean_dataframe(df)
        df['updated_on'] = pd.to_datetime(df['updated_on']).dt.strftime('%Y-%m-%d %H:%M:%S')
        
        chunk_size = 1000
        total_rows = len(df)
        
        # First connection to disable foreign key checks
        with engine.connect() as conn1:
            conn1.execute(text("SET FOREIGN_KEY_CHECKS=0"))
        
        # Second connection for data import
        with engine.connect() as conn2:
            with conn2.begin():
                for i in range(0, total_rows, chunk_size):
                    chunk = df.iloc[i:i + chunk_size]
                    
                    records = [{
                        'track_id': str(row['track_id']),
                        'artist_id': str(row['artist_id']),
                        'updated_on': row['updated_on']
                    } for _, row in chunk.iterrows()]
                    
                    insert_stmt = text("""
                        INSERT IGNORE INTO artist_track (track_id, artist_id, updated_on)
                        VALUES (:track_id, :artist_id, :updated_on)
                    """)
                    
                    conn2.execute(insert_stmt, records)
                    print(f"Processed {min(i + chunk_size, total_rows)} out of {total_rows} artist-track relationships")
        
        # Third connection to re-enable foreign key checks
        with engine.connect() as conn3:
            conn3.execute(text("SET FOREIGN_KEY_CHECKS=1"))
            
        print("Artist-track relationships imported successfully")
                
    except Exception as e:
        print(f"Error importing artist-track relationships: {str(e)}")
        raise

# %%
def main():
    """Main function to create schema and import data"""
    try:
        engine = create_mysql_engine()
        
        # Import data table by table
        import_artist_tracks(engine)

        
        print("All data imported successfully!")
    except Exception as e:
        print(f"Error in main execution: {str(e)}")
        raise

if __name__ == "__main__":
    main()
# Out:
# Importing artist-track relationships...
# Processed 1000 out of 7716591 artist-track relationships
# Processed 2000 out of 7716591 artist-track relationships
# Processed 3000 out of 7716591 artist-track relationships
# Processed 4000 out of 7716591 artist-track relationships
# Processed 5000 out of 7716591 artist-track relationships
# Processed 6000 out of 7716591 artist-track relationships
# Processed 7000 out of 7716591 artist-track relationships
# Processed 8000 out of 7716591 artist-track relationships
# Processed 9000 out of 7716591 artist-track relationships
# Processed 10000 out of 7716591 artist-track relationships
# Processed 11000 out of 7716591 artist-track relationships
# Processed 12000 out of 7716591 artist-track relationships
# Processed 13000 out of 7716591 artist-track relationships
# Processed 14000 out of 7716591 artist-track relationships
# Processed 15000 out of 7716591 artist-track relationships
# Processed 16000 out of 7716591 artist-track relationships
# Processed 17000 out of 7716591 artist-track relationships
# Processed 18000 out of 7716591 artist-track relationships
# Processed 19000 out of 7716591 artist-track relationships
# Processed 20000 out of 7716591 artist-track relationships
# Processed 21000 out of 7716591 artist-track relationships
# Processed 22000 out of 7716591 artist-track relationships
# Processed 23000 out of 7716591 artist-track relationships
# Processed 24000 out of 7716591 artist-track relationships
# Processed 25000 out of 7716591 artist-track relationships
# Processed 26000 out of 7716591 artist-track relationships
# Processed 27000 out of 7716591 artist-track relationships
# Processed 28000 out of 7716591 artist-track relationships
# Processed 29000 out of 7716591 artist-track relationships
# Processed 30000 out of 7716591 artist-track relationships
# Processed 31000 out of 7716591 artist-track relationships
# Processed 32000 out of 7716591 artist-track relationships
# Processed 33000 out of 7716591 artist-track relationships
# Processed 34000 out of 7716591 artist-track relationships
# Processed 35000 out of 7716591 artist-track relationships
# Processed 36000 out of 7716591 artist-track relationships
# Processed 37000 out of 7716591 artist-track relationships
# Processed 38000 out of 7716591 artist-track relationships
# Processed 39000 out of 7716591 artist-track relationships
# Processed 40000 out of 7716591 artist-track relationships
# Processed 41000 out of 7716591 artist-track relationships
# Processed 42000 out of 7716591 artist-track relationships
# Processed 43000 out of 7716591 artist-track relationships
# Processed 44000 out of 7716591 artist-track relationships
# Processed 45000 out of 7716591 artist-track relationships
# Processed 46000 out of 7716591 artist-track relationships
# Processed 47000 out of 7716591 artist-track relationships
# Processed 48000 out of 7716591 artist-track relationships
# Processed 49000 out of 7716591 artist-track relationships
# Processed 50000 out of 7716591 artist-track relationships
# Processed 51000 out of 7716591 artist-track relationships
# Processed 52000 out of 7716591 artist-track relationships
# Processed 53000 out of 7716591 artist-track relationships
# Processed 54000 out of 7716591 artist-track relationships
# Processed 55000 out of 7716591 artist-track relationships
# Processed 56000 out of 7716591 artist-track relationships
# Processed 57000 out of 7716591 artist-track relationships
# Processed 58000 out of 7716591 artist-track relationships
# Processed 59000 out of 7716591 artist-track relationships
# Processed 60000 out of 7716591 artist-track relationships
# Processed 61000 out of 7716591 artist-track relationships
# Processed 62000 out of 7716591 artist-track relationships
# Processed 63000 out of 7716591 artist-track relationships
# Processed 64000 out of 7716591 artist-track relationships
# Processed 65000 out of 7716591 artist-track relationships
# Processed 66000 out of 7716591 artist-track relationships
# Processed 67000 out of 7716591 artist-track relationships
# Processed 68000 out of 7716591 artist-track relationships
# Processed 69000 out of 7716591 artist-track relationships
# Processed 70000 out of 7716591 artist-track relationships
# Processed 71000 out of 7716591 artist-track relationships
# Processed 72000 out of 7716591 artist-track relationships
# Processed 73000 out of 7716591 artist-track relationships
# Processed 74000 out of 7716591 artist-track relationships
# Processed 75000 out of 7716591 artist-track relationships
# Processed 76000 out of 7716591 artist-track relationships
# Processed 77000 out of 7716591 artist-track relationships
# Processed 78000 out of 7716591 artist-track relationships
# Processed 79000 out of 7716591 artist-track relationships
# Processed 80000 out of 7716591 artist-track relationships
# Processed 81000 out of 7716591 artist-track relationships
# Processed 82000 out of 7716591 artist-track relationships
# Processed 83000 out of 7716591 artist-track relationships
# Processed 84000 out of 7716591 artist-track relationships
# Processed 85000 out of 7716591 artist-track relationships
# Processed 86000 out of 7716591 artist-track relationships
# Processed 87000 out of 7716591 artist-track relationships
# Processed 88000 out of 7716591 artist-track relationships
# Processed 89000 out of 7716591 artist-track relationships
# Processed 90000 out of 7716591 artist-track relationships
# Processed 91000 out of 7716591 artist-track relationships
# Processed 92000 out of 7716591 artist-track relationships
# Processed 93000 out of 7716591 artist-track relationships
# Processed 94000 out of 7716591 artist-track relationships
# Processed 95000 out of 7716591 artist-track relationships
# Processed 96000 out of 7716591 artist-track relationships
# Processed 97000 out of 7716591 artist-track relationships
# Processed 98000 out of 7716591 artist-track relationships
# Processed 99000 out of 7716591 artist-track relationships
# Processed 100000 out of 7716591 artist-track relationships
# Processed 101000 out of 7716591 artist-track relationships
# Processed 102000 out of 7716591 artist-track relationships
# Processed 103000 out of 7716591 artist-track relationships
# Processed 104000 out of 7716591 artist-track relationships
# Processed 105000 out of 7716591 artist-track relationships
# Processed 106000 out of 7716591 artist-track relationships
# Processed 107000 out of 7716591 artist-track relationships
# Processed 108000 out of 7716591 artist-track relationships
# Processed 109000 out of 7716591 artist-track relationships
# Processed 110000 out of 7716591 artist-track relationships
# Processed 111000 out of 7716591 artist-track relationships
# Processed 112000 out of 7716591 artist-track relationships
# Processed 113000 out of 7716591 artist-track relationships
# Processed 114000 out of 7716591 artist-track relationships
# Processed 115000 out of 7716591 artist-track relationships
# Processed 116000 out of 7716591 artist-track relationships
# Processed 117000 out of 7716591 artist-track relationships
# Processed 118000 out of 7716591 artist-track relationships
# Processed 119000 out of 7716591 artist-track relationships
# Processed 120000 out of 7716591 artist-track relationships
# Processed 121000 out of 7716591 artist-track relationships
# Processed 122000 out of 7716591 artist-track relationships
# Processed 123000 out of 7716591 artist-track relationships
# Processed 124000 out of 7716591 artist-track relationships
# Processed 125000 out of 7716591 artist-track relationships
# Processed 126000 out of 7716591 artist-track relationships
# Processed 127000 out of 7716591 artist-track relationships
# Processed 128000 out of 7716591 artist-track relationships
# Processed 129000 out of 7716591 artist-track relationships
# Processed 130000 out of 7716591 artist-track relationships
# Processed 131000 out of 7716591 artist-track relationships
# Processed 132000 out of 7716591 artist-track relationships
# Processed 133000 out of 7716591 artist-track relationships
# Processed 134000 out of 7716591 artist-track relationships
# Processed 135000 out of 7716591 artist-track relationships
# Processed 136000 out of 7716591 artist-track relationships
# Processed 137000 out of 7716591 artist-track relationships
# Processed 138000 out of 7716591 artist-track relationships
# Processed 139000 out of 7716591 artist-track relationships
# Processed 140000 out of 7716591 artist-track relationships
# Processed 141000 out of 7716591 artist-track relationships
# Processed 142000 out of 7716591 artist-track relationships
# Processed 143000 out of 7716591 artist-track relationships
# Processed 144000 out of 7716591 artist-track relationships
# Processed 145000 out of 7716591 artist-track relationships
# Processed 146000 out of 7716591 artist-track relationships
# Processed 147000 out of 7716591 artist-track relationships
# Processed 148000 out of 7716591 artist-track relationships
# Processed 149000 out of 7716591 artist-track relationships
# Processed 150000 out of 7716591 artist-track relationships
# Processed 151000 out of 7716591 artist-track relationships
# Processed 152000 out of 7716591 artist-track relationships
# Processed 153000 out of 7716591 artist-track relationships
# Processed 154000 out of 7716591 artist-track relationships
# Processed 155000 out of 7716591 artist-track relationships
# Processed 156000 out of 7716591 artist-track relationships
# Processed 157000 out of 7716591 artist-track relationships
# Processed 158000 out of 7716591 artist-track relationships
# Processed 159000 out of 7716591 artist-track relationships
# Processed 160000 out of 7716591 artist-track relationships
# Processed 161000 out of 7716591 artist-track relationships
# Processed 162000 out of 7716591 artist-track relationships
# Processed 163000 out of 7716591 artist-track relationships
# Processed 164000 out of 7716591 artist-track relationships
# Processed 165000 out of 7716591 artist-track relationships
# Processed 166000 out of 7716591 artist-track relationships
# Processed 167000 out of 7716591 artist-track relationships
# Processed 168000 out of 7716591 artist-track relationships
# Processed 169000 out of 7716591 artist-track relationships
# Processed 170000 out of 7716591 artist-track relationships
# Processed 171000 out of 7716591 artist-track relationships
# Processed 172000 out of 7716591 artist-track relationships
# Processed 173000 out of 7716591 artist-track relationships
# Processed 174000 out of 7716591 artist-track relationships
# Processed 175000 out of 7716591 artist-track relationships
# Processed 176000 out of 7716591 artist-track relationships
# Processed 177000 out of 7716591 artist-track relationships
# Processed 178000 out of 7716591 artist-track relationships
# Processed 179000 out of 7716591 artist-track relationships
# Processed 180000 out of 7716591 artist-track relationships
# Processed 181000 out of 7716591 artist-track relationships
# Processed 182000 out of 7716591 artist-track relationships
# Processed 183000 out of 7716591 artist-track relationships
# Processed 184000 out of 7716591 artist-track relationships
# Processed 185000 out of 7716591 artist-track relationships
# Processed 186000 out of 7716591 artist-track relationships
# Processed 187000 out of 7716591 artist-track relationships
# Processed 188000 out of 7716591 artist-track relationships
# Processed 189000 out of 7716591 artist-track relationships
# Processed 190000 out of 7716591 artist-track relationships
# Processed 191000 out of 7716591 artist-track relationships
# Processed 192000 out of 7716591 artist-track relationships
# Processed 193000 out of 7716591 artist-track relationships
# Processed 194000 out of 7716591 artist-track relationships
# Processed 195000 out of 7716591 artist-track relationships
# Processed 196000 out of 7716591 artist-track relationships
# Processed 197000 out of 7716591 artist-track relationships
# Processed 198000 out of 7716591 artist-track relationships
# Processed 199000 out of 7716591 artist-track relationships
# Processed 200000 out of 7716591 artist-track relationships
# Processed 201000 out of 7716591 artist-track relationships
# Processed 202000 out of 7716591 artist-track relationships
# Processed 203000 out of 7716591 artist-track relationships
# Processed 204000 out of 7716591 artist-track relationships
# Processed 205000 out of 7716591 artist-track relationships
# Processed 206000 out of 7716591 artist-track relationships
# Processed 207000 out of 7716591 artist-track relationships
# Processed 208000 out of 7716591 artist-track relationships
# Processed 209000 out of 7716591 artist-track relationships
# Processed 210000 out of 7716591 artist-track relationships
# Processed 211000 out of 7716591 artist-track relationships
# Processed 212000 out of 7716591 artist-track relationships
# Processed 213000 out of 7716591 artist-track relationships
# Processed 214000 out of 7716591 artist-track relationships
# Processed 215000 out of 7716591 artist-track relationships
# Processed 216000 out of 7716591 artist-track relationships
# Processed 217000 out of 7716591 artist-track relationships
# Processed 218000 out of 7716591 artist-track relationships
# Processed 219000 out of 7716591 artist-track relationships
# Processed 220000 out of 7716591 artist-track relationships
# Processed 221000 out of 7716591 artist-track relationships
# Processed 222000 out of 7716591 artist-track relationships
# Processed 223000 out of 7716591 artist-track relationships
# Processed 224000 out of 7716591 artist-track relationships
# Processed 225000 out of 7716591 artist-track relationships
# Processed 226000 out of 7716591 artist-track relationships
# Processed 227000 out of 7716591 artist-track relationships
# Processed 228000 out of 7716591 artist-track relationships
# Processed 229000 out of 7716591 artist-track relationships
# Processed 230000 out of 7716591 artist-track relationships
# Processed 231000 out of 7716591 artist-track relationships
# Processed 232000 out of 7716591 artist-track relationships
# Processed 233000 out of 7716591 artist-track relationships
# Processed 234000 out of 7716591 artist-track relationships
# Processed 235000 out of 7716591 artist-track relationships
# Processed 236000 out of 7716591 artist-track relationships
# Processed 237000 out of 7716591 artist-track relationships
# Processed 238000 out of 7716591 artist-track relationships
# Processed 239000 out of 7716591 artist-track relationships
# Processed 240000 out of 7716591 artist-track relationships
# Processed 241000 out of 7716591 artist-track relationships
# Processed 242000 out of 7716591 artist-track relationships
# Processed 243000 out of 7716591 artist-track relationships
# Processed 244000 out of 7716591 artist-track relationships
# Processed 245000 out of 7716591 artist-track relationships
# Processed 246000 out of 7716591 artist-track relationships
# Processed 247000 out of 7716591 artist-track relationships
# Processed 248000 out of 7716591 artist-track relationships
# Processed 249000 out of 7716591 artist-track relationships
# Processed 250000 out of 7716591 artist-track relationships
# Processed 251000 out of 7716591 artist-track relationships
# Processed 252000 out of 7716591 artist-track relationships
# Processed 253000 out of 7716591 artist-track relationships
# Processed 254000 out of 7716591 artist-track relationships
# Processed 255000 out of 7716591 artist-track relationships
# Processed 256000 out of 7716591 artist-track relationships
# Processed 257000 out of 7716591 artist-track relationships
# Processed 258000 out of 7716591 artist-track relationships
# Processed 259000 out of 7716591 artist-track relationships
# Processed 260000 out of 7716591 artist-track relationships
# Processed 261000 out of 7716591 artist-track relationships
# Processed 262000 out of 7716591 artist-track relationships
# Processed 263000 out of 7716591 artist-track relationships
# Processed 264000 out of 7716591 artist-track relationships
# Processed 265000 out of 7716591 artist-track relationships
# Processed 266000 out of 7716591 artist-track relationships
# Processed 267000 out of 7716591 artist-track relationships
# Processed 268000 out of 7716591 artist-track relationships
# Processed 269000 out of 7716591 artist-track relationships
# Processed 270000 out of 7716591 artist-track relationships
# Processed 271000 out of 7716591 artist-track relationships
# Processed 272000 out of 7716591 artist-track relationships
# Processed 273000 out of 7716591 artist-track relationships
# Processed 274000 out of 7716591 artist-track relationships
# Processed 275000 out of 7716591 artist-track relationships
# Processed 276000 out of 7716591 artist-track relationships
# Processed 277000 out of 7716591 artist-track relationships
# Processed 278000 out of 7716591 artist-track relationships
# Processed 279000 out of 7716591 artist-track relationships
# Processed 280000 out of 7716591 artist-track relationships
# Processed 281000 out of 7716591 artist-track relationships
# Processed 282000 out of 7716591 artist-track relationships
# Processed 283000 out of 7716591 artist-track relationships
# Processed 284000 out of 7716591 artist-track relationships
# Processed 285000 out of 7716591 artist-track relationships
# Processed 286000 out of 7716591 artist-track relationships
# Processed 287000 out of 7716591 artist-track relationships
# Processed 288000 out of 7716591 artist-track relationships
# Processed 289000 out of 7716591 artist-track relationships
# Processed 290000 out of 7716591 artist-track relationships
# Processed 291000 out of 7716591 artist-track relationships
# Processed 292000 out of 7716591 artist-track relationships
# Processed 293000 out of 7716591 artist-track relationships
# Processed 294000 out of 7716591 artist-track relationships
# Processed 295000 out of 7716591 artist-track relationships
# Processed 296000 out of 7716591 artist-track relationships
# Processed 297000 out of 7716591 artist-track relationships
# Processed 298000 out of 7716591 artist-track relationships
# Processed 299000 out of 7716591 artist-track relationships
# Processed 300000 out of 7716591 artist-track relationships
# Processed 301000 out of 7716591 artist-track relationships
# Processed 302000 out of 7716591 artist-track relationships
# Processed 303000 out of 7716591 artist-track relationships
# Processed 304000 out of 7716591 artist-track relationships
# Processed 305000 out of 7716591 artist-track relationships
# Processed 306000 out of 7716591 artist-track relationships
# Processed 307000 out of 7716591 artist-track relationships
# Processed 308000 out of 7716591 artist-track relationships
# Processed 309000 out of 7716591 artist-track relationships
# Processed 310000 out of 7716591 artist-track relationships
# Processed 311000 out of 7716591 artist-track relationships
# Processed 312000 out of 7716591 artist-track relationships
# Processed 313000 out of 7716591 artist-track relationships
# Processed 314000 out of 7716591 artist-track relationships
# Processed 315000 out of 7716591 artist-track relationships
# Processed 316000 out of 7716591 artist-track relationships
# Processed 317000 out of 7716591 artist-track relationships
# Processed 318000 out of 7716591 artist-track relationships
# Processed 319000 out of 7716591 artist-track relationships
# Processed 320000 out of 7716591 artist-track relationships
# Processed 321000 out of 7716591 artist-track relationships
# Processed 322000 out of 7716591 artist-track relationships
# Processed 323000 out of 7716591 artist-track relationships
# Processed 324000 out of 7716591 artist-track relationships
# Processed 325000 out of 7716591 artist-track relationships
# Processed 326000 out of 7716591 artist-track relationships
# Processed 327000 out of 7716591 artist-track relationships
# Processed 328000 out of 7716591 artist-track relationships
# Processed 329000 out of 7716591 artist-track relationships
# Processed 330000 out of 7716591 artist-track relationships
# Processed 331000 out of 7716591 artist-track relationships
# Processed 332000 out of 7716591 artist-track relationships
# Processed 333000 out of 7716591 artist-track relationships
# Processed 334000 out of 7716591 artist-track relationships
# Processed 335000 out of 7716591 artist-track relationships
# Processed 336000 out of 7716591 artist-track relationships
# Processed 337000 out of 7716591 artist-track relationships
# Processed 338000 out of 7716591 artist-track relationships
# Processed 339000 out of 7716591 artist-track relationships
# Processed 340000 out of 7716591 artist-track relationships
# Processed 341000 out of 7716591 artist-track relationships
# Processed 342000 out of 7716591 artist-track relationships
# Processed 343000 out of 7716591 artist-track relationships
# Processed 344000 out of 7716591 artist-track relationships
# Processed 345000 out of 7716591 artist-track relationships
# Processed 346000 out of 7716591 artist-track relationships
# Processed 347000 out of 7716591 artist-track relationships
# Processed 348000 out of 7716591 artist-track relationships
# Processed 349000 out of 7716591 artist-track relationships
# Processed 350000 out of 7716591 artist-track relationships
# Processed 351000 out of 7716591 artist-track relationships
# Processed 352000 out of 7716591 artist-track relationships
# Processed 353000 out of 7716591 artist-track relationships
# Processed 354000 out of 7716591 artist-track relationships
# Processed 355000 out of 7716591 artist-track relationships
# Processed 356000 out of 7716591 artist-track relationships
# Processed 357000 out of 7716591 artist-track relationships
# Processed 358000 out of 7716591 artist-track relationships
# Processed 359000 out of 7716591 artist-track relationships
# Processed 360000 out of 7716591 artist-track relationships
# Processed 361000 out of 7716591 artist-track relationships
# Processed 362000 out of 7716591 artist-track relationships
# Processed 363000 out of 7716591 artist-track relationships
# Processed 364000 out of 7716591 artist-track relationships
# Processed 365000 out of 7716591 artist-track relationships
# Processed 366000 out of 7716591 artist-track relationships
# Processed 367000 out of 7716591 artist-track relationships
# Processed 368000 out of 7716591 artist-track relationships
# Processed 369000 out of 7716591 artist-track relationships
# Processed 370000 out of 7716591 artist-track relationships
# Processed 371000 out of 7716591 artist-track relationships
# Processed 372000 out of 7716591 artist-track relationships
# Processed 373000 out of 7716591 artist-track relationships
# Processed 374000 out of 7716591 artist-track relationships
# Processed 375000 out of 7716591 artist-track relationships
# Processed 376000 out of 7716591 artist-track relationships
# Processed 377000 out of 7716591 artist-track relationships
# Processed 378000 out of 7716591 artist-track relationships
# Processed 379000 out of 7716591 artist-track relationships
# Processed 380000 out of 7716591 artist-track relationships
# Processed 381000 out of 7716591 artist-track relationships
# Processed 382000 out of 7716591 artist-track relationships
# Processed 383000 out of 7716591 artist-track relationships
# Processed 384000 out of 7716591 artist-track relationships
# Processed 385000 out of 7716591 artist-track relationships
# Processed 386000 out of 7716591 artist-track relationships
# Processed 387000 out of 7716591 artist-track relationships
# Processed 388000 out of 7716591 artist-track relationships
# Processed 389000 out of 7716591 artist-track relationships
# Processed 390000 out of 7716591 artist-track relationships
# Processed 391000 out of 7716591 artist-track relationships
# Processed 392000 out of 7716591 artist-track relationships
# Processed 393000 out of 7716591 artist-track relationships
# Processed 394000 out of 7716591 artist-track relationships
# Processed 395000 out of 7716591 artist-track relationships
# Processed 396000 out of 7716591 artist-track relationships
# Processed 397000 out of 7716591 artist-track relationships
# Processed 398000 out of 7716591 artist-track relationships
# Processed 399000 out of 7716591 artist-track relationships
# Processed 400000 out of 7716591 artist-track relationships
# Processed 401000 out of 7716591 artist-track relationships
# Processed 402000 out of 7716591 artist-track relationships
# Processed 403000 out of 7716591 artist-track relationships
# Processed 404000 out of 7716591 artist-track relationships
# Processed 405000 out of 7716591 artist-track relationships
# Processed 406000 out of 7716591 artist-track relationships
# Processed 407000 out of 7716591 artist-track relationships
# Processed 408000 out of 7716591 artist-track relationships
# Processed 409000 out of 7716591 artist-track relationships
# Processed 410000 out of 7716591 artist-track relationships
# Processed 411000 out of 7716591 artist-track relationships
# Processed 412000 out of 7716591 artist-track relationships
# Processed 413000 out of 7716591 artist-track relationships
# Processed 414000 out of 7716591 artist-track relationships
# Processed 415000 out of 7716591 artist-track relationships
# Processed 416000 out of 7716591 artist-track relationships
# Processed 417000 out of 7716591 artist-track relationships
# Processed 418000 out of 7716591 artist-track relationships
# Processed 419000 out of 7716591 artist-track relationships
# Processed 420000 out of 7716591 artist-track relationships
# Processed 421000 out of 7716591 artist-track relationships
# Processed 422000 out of 7716591 artist-track relationships
# Processed 423000 out of 7716591 artist-track relationships
# Processed 424000 out of 7716591 artist-track relationships
# Processed 425000 out of 7716591 artist-track relationships
# Processed 426000 out of 7716591 artist-track relationships
# Processed 427000 out of 7716591 artist-track relationships
# Processed 428000 out of 7716591 artist-track relationships
# Processed 429000 out of 7716591 artist-track relationships
# Processed 430000 out of 7716591 artist-track relationships
# Processed 431000 out of 7716591 artist-track relationships
# Processed 432000 out of 7716591 artist-track relationships
# Processed 433000 out of 7716591 artist-track relationships
# Processed 434000 out of 7716591 artist-track relationships
# Processed 435000 out of 7716591 artist-track relationships
# Processed 436000 out of 7716591 artist-track relationships
# Processed 437000 out of 7716591 artist-track relationships
# Processed 438000 out of 7716591 artist-track relationships
# Processed 439000 out of 7716591 artist-track relationships
# Processed 440000 out of 7716591 artist-track relationships
# Processed 441000 out of 7716591 artist-track relationships
# Processed 442000 out of 7716591 artist-track relationships
# Processed 443000 out of 7716591 artist-track relationships
# Processed 444000 out of 7716591 artist-track relationships
# Processed 445000 out of 7716591 artist-track relationships
# Processed 446000 out of 7716591 artist-track relationships
# Processed 447000 out of 7716591 artist-track relationships
# Processed 448000 out of 7716591 artist-track relationships
# Processed 449000 out of 7716591 artist-track relationships
# Processed 450000 out of 7716591 artist-track relationships
# Processed 451000 out of 7716591 artist-track relationships
# Processed 452000 out of 7716591 artist-track relationships
# Processed 453000 out of 7716591 artist-track relationships
# Processed 454000 out of 7716591 artist-track relationships
# Processed 455000 out of 7716591 artist-track relationships
# Processed 456000 out of 7716591 artist-track relationships
# Processed 457000 out of 7716591 artist-track relationships
# Processed 458000 out of 7716591 artist-track relationships
# Processed 459000 out of 7716591 artist-track relationships
# Processed 460000 out of 7716591 artist-track relationships
# Processed 461000 out of 7716591 artist-track relationships
# Processed 462000 out of 7716591 artist-track relationships
# Processed 463000 out of 7716591 artist-track relationships
# Processed 464000 out of 7716591 artist-track relationships
# Processed 465000 out of 7716591 artist-track relationships
# Processed 466000 out of 7716591 artist-track relationships
# Processed 467000 out of 7716591 artist-track relationships
# Processed 468000 out of 7716591 artist-track relationships
# Processed 469000 out of 7716591 artist-track relationships
# Processed 470000 out of 7716591 artist-track relationships
# Processed 471000 out of 7716591 artist-track relationships
# Processed 472000 out of 7716591 artist-track relationships
# Processed 473000 out of 7716591 artist-track relationships
# Processed 474000 out of 7716591 artist-track relationships
# Processed 475000 out of 7716591 artist-track relationships
# Processed 476000 out of 7716591 artist-track relationships
# Processed 477000 out of 7716591 artist-track relationships
# Processed 478000 out of 7716591 artist-track relationships
# Processed 479000 out of 7716591 artist-track relationships
# Processed 480000 out of 7716591 artist-track relationships
# Processed 481000 out of 7716591 artist-track relationships
# Processed 482000 out of 7716591 artist-track relationships
# Processed 483000 out of 7716591 artist-track relationships
# Processed 484000 out of 7716591 artist-track relationships
# Processed 485000 out of 7716591 artist-track relationships
# Processed 486000 out of 7716591 artist-track relationships
# Processed 487000 out of 7716591 artist-track relationships
# Processed 488000 out of 7716591 artist-track relationships
# Processed 489000 out of 7716591 artist-track relationships
# Processed 490000 out of 7716591 artist-track relationships
# Processed 491000 out of 7716591 artist-track relationships
# Processed 492000 out of 7716591 artist-track relationships
# Processed 493000 out of 7716591 artist-track relationships
# Processed 494000 out of 7716591 artist-track relationships
# Processed 495000 out of 7716591 artist-track relationships
# Processed 496000 out of 7716591 artist-track relationships
# Processed 497000 out of 7716591 artist-track relationships
# Processed 498000 out of 7716591 artist-track relationships
# Processed 499000 out of 7716591 artist-track relationships
# Processed 500000 out of 7716591 artist-track relationships
# Processed 501000 out of 7716591 artist-track relationships
# Processed 502000 out of 7716591 artist-track relationships
# Processed 503000 out of 7716591 artist-track relationships
# Processed 504000 out of 7716591 artist-track relationships
# Processed 505000 out of 7716591 artist-track relationships
# Processed 506000 out of 7716591 artist-track relationships
# Processed 507000 out of 7716591 artist-track relationships
# Processed 508000 out of 7716591 artist-track relationships
# Processed 509000 out of 7716591 artist-track relationships
# Processed 510000 out of 7716591 artist-track relationships
# Processed 511000 out of 7716591 artist-track relationships
# Processed 512000 out of 7716591 artist-track relationships
# Processed 513000 out of 7716591 artist-track relationships
# Processed 514000 out of 7716591 artist-track relationships
# Processed 515000 out of 7716591 artist-track relationships
# Processed 516000 out of 7716591 artist-track relationships
# Processed 517000 out of 7716591 artist-track relationships
# Processed 518000 out of 7716591 artist-track relationships
# Processed 519000 out of 7716591 artist-track relationships
# Processed 520000 out of 7716591 artist-track relationships
# Processed 521000 out of 7716591 artist-track relationships
# Processed 522000 out of 7716591 artist-track relationships
# Processed 523000 out of 7716591 artist-track relationships
# Processed 524000 out of 7716591 artist-track relationships
# Processed 525000 out of 7716591 artist-track relationships
# Processed 526000 out of 7716591 artist-track relationships
# Processed 527000 out of 7716591 artist-track relationships
# Processed 528000 out of 7716591 artist-track relationships
# Processed 529000 out of 7716591 artist-track relationships
# Processed 530000 out of 7716591 artist-track relationships
# Processed 531000 out of 7716591 artist-track relationships
# Processed 532000 out of 7716591 artist-track relationships
# Processed 533000 out of 7716591 artist-track relationships
# Processed 534000 out of 7716591 artist-track relationships
# Processed 535000 out of 7716591 artist-track relationships
# Processed 536000 out of 7716591 artist-track relationships
# Processed 537000 out of 7716591 artist-track relationships
# Processed 538000 out of 7716591 artist-track relationships
# Processed 539000 out of 7716591 artist-track relationships
# Processed 540000 out of 7716591 artist-track relationships
# Processed 541000 out of 7716591 artist-track relationships
# Processed 542000 out of 7716591 artist-track relationships
# Processed 543000 out of 7716591 artist-track relationships
# Processed 544000 out of 7716591 artist-track relationships
# Processed 545000 out of 7716591 artist-track relationships
# Processed 546000 out of 7716591 artist-track relationships
# Processed 547000 out of 7716591 artist-track relationships
# Processed 548000 out of 7716591 artist-track relationships
# Processed 549000 out of 7716591 artist-track relationships
# Processed 550000 out of 7716591 artist-track relationships
# Processed 551000 out of 7716591 artist-track relationships
# Processed 552000 out of 7716591 artist-track relationships
# Processed 553000 out of 7716591 artist-track relationships
# Processed 554000 out of 7716591 artist-track relationships
# Processed 555000 out of 7716591 artist-track relationships
# Processed 556000 out of 7716591 artist-track relationships
# Processed 557000 out of 7716591 artist-track relationships
# Processed 558000 out of 7716591 artist-track relationships
# Processed 559000 out of 7716591 artist-track relationships
# Processed 560000 out of 7716591 artist-track relationships
# Processed 561000 out of 7716591 artist-track relationships
# Processed 562000 out of 7716591 artist-track relationships
# Processed 563000 out of 7716591 artist-track relationships
# Processed 564000 out of 7716591 artist-track relationships
# Processed 565000 out of 7716591 artist-track relationships
# Processed 566000 out of 7716591 artist-track relationships
# Processed 567000 out of 7716591 artist-track relationships
# Processed 568000 out of 7716591 artist-track relationships
# Processed 569000 out of 7716591 artist-track relationships
# Processed 570000 out of 7716591 artist-track relationships
# Processed 571000 out of 7716591 artist-track relationships
# Processed 572000 out of 7716591 artist-track relationships
# Processed 573000 out of 7716591 artist-track relationships
# Processed 574000 out of 7716591 artist-track relationships
# Processed 575000 out of 7716591 artist-track relationships
# Processed 576000 out of 7716591 artist-track relationships
# Processed 577000 out of 7716591 artist-track relationships
# Processed 578000 out of 7716591 artist-track relationships
# Processed 579000 out of 7716591 artist-track relationships
# Processed 580000 out of 7716591 artist-track relationships
# Processed 581000 out of 7716591 artist-track relationships
# Processed 582000 out of 7716591 artist-track relationships
# Processed 583000 out of 7716591 artist-track relationships
# Processed 584000 out of 7716591 artist-track relationships
# Processed 585000 out of 7716591 artist-track relationships
# Processed 586000 out of 7716591 artist-track relationships
# Processed 587000 out of 7716591 artist-track relationships
# Processed 588000 out of 7716591 artist-track relationships
# Processed 589000 out of 7716591 artist-track relationships
# Processed 590000 out of 7716591 artist-track relationships
# Processed 591000 out of 7716591 artist-track relationships
# Processed 592000 out of 7716591 artist-track relationships
# Processed 593000 out of 7716591 artist-track relationships
# Processed 594000 out of 7716591 artist-track relationships
# Processed 595000 out of 7716591 artist-track relationships
# Processed 596000 out of 7716591 artist-track relationships
# Processed 597000 out of 7716591 artist-track relationships
# Processed 598000 out of 7716591 artist-track relationships
# Processed 599000 out of 7716591 artist-track relationships
# Processed 600000 out of 7716591 artist-track relationships
# Processed 601000 out of 7716591 artist-track relationships
# Processed 602000 out of 7716591 artist-track relationships
# Processed 603000 out of 7716591 artist-track relationships
# Processed 604000 out of 7716591 artist-track relationships
# Processed 605000 out of 7716591 artist-track relationships
# Processed 606000 out of 7716591 artist-track relationships
# Processed 607000 out of 7716591 artist-track relationships
# Processed 608000 out of 7716591 artist-track relationships
# Processed 609000 out of 7716591 artist-track relationships
# Processed 610000 out of 7716591 artist-track relationships
# Processed 611000 out of 7716591 artist-track relationships
# Processed 612000 out of 7716591 artist-track relationships
# Processed 613000 out of 7716591 artist-track relationships
# Processed 614000 out of 7716591 artist-track relationships
# Processed 615000 out of 7716591 artist-track relationships
# Processed 616000 out of 7716591 artist-track relationships
# Processed 617000 out of 7716591 artist-track relationships
# Processed 618000 out of 7716591 artist-track relationships
# Processed 619000 out of 7716591 artist-track relationships
# Processed 620000 out of 7716591 artist-track relationships
# Processed 621000 out of 7716591 artist-track relationships
# Processed 622000 out of 7716591 artist-track relationships
# Processed 623000 out of 7716591 artist-track relationships
# Processed 624000 out of 7716591 artist-track relationships
# Processed 625000 out of 7716591 artist-track relationships
# Processed 626000 out of 7716591 artist-track relationships
# Processed 627000 out of 7716591 artist-track relationships
# Processed 628000 out of 7716591 artist-track relationships
# Processed 629000 out of 7716591 artist-track relationships
# Processed 630000 out of 7716591 artist-track relationships
# Processed 631000 out of 7716591 artist-track relationships
# Processed 632000 out of 7716591 artist-track relationships
# Processed 633000 out of 7716591 artist-track relationships
# Processed 634000 out of 7716591 artist-track relationships
# Processed 635000 out of 7716591 artist-track relationships
# Processed 636000 out of 7716591 artist-track relationships
# Processed 637000 out of 7716591 artist-track relationships
# Processed 638000 out of 7716591 artist-track relationships
# Processed 639000 out of 7716591 artist-track relationships
# Processed 640000 out of 7716591 artist-track relationships
# Processed 641000 out of 7716591 artist-track relationships
# Processed 642000 out of 7716591 artist-track relationships
# Processed 643000 out of 7716591 artist-track relationships
# Processed 644000 out of 7716591 artist-track relationships
# Processed 645000 out of 7716591 artist-track relationships
# Processed 646000 out of 7716591 artist-track relationships
# Processed 647000 out of 7716591 artist-track relationships
# Processed 648000 out of 7716591 artist-track relationships
# Processed 649000 out of 7716591 artist-track relationships
# Processed 650000 out of 7716591 artist-track relationships
# Processed 651000 out of 7716591 artist-track relationships
# Processed 652000 out of 7716591 artist-track relationships
# Processed 653000 out of 7716591 artist-track relationships
# Processed 654000 out of 7716591 artist-track relationships
# Processed 655000 out of 7716591 artist-track relationships
# Processed 656000 out of 7716591 artist-track relationships
# Processed 657000 out of 7716591 artist-track relationships
# Processed 658000 out of 7716591 artist-track relationships
# Processed 659000 out of 7716591 artist-track relationships
# Processed 660000 out of 7716591 artist-track relationships
# Processed 661000 out of 7716591 artist-track relationships
# Processed 662000 out of 7716591 artist-track relationships
# Processed 663000 out of 7716591 artist-track relationships
# Processed 664000 out of 7716591 artist-track relationships
# Processed 665000 out of 7716591 artist-track relationships
# Processed 666000 out of 7716591 artist-track relationships
# Processed 667000 out of 7716591 artist-track relationships
# Processed 668000 out of 7716591 artist-track relationships
# Processed 669000 out of 7716591 artist-track relationships
# Processed 670000 out of 7716591 artist-track relationships
# Processed 671000 out of 7716591 artist-track relationships
# Processed 672000 out of 7716591 artist-track relationships
# Processed 673000 out of 7716591 artist-track relationships
# Processed 674000 out of 7716591 artist-track relationships
# Processed 675000 out of 7716591 artist-track relationships
# Processed 676000 out of 7716591 artist-track relationships
# Processed 677000 out of 7716591 artist-track relationships
# Processed 678000 out of 7716591 artist-track relationships
# Processed 679000 out of 7716591 artist-track relationships
# Processed 680000 out of 7716591 artist-track relationships
# Processed 681000 out of 7716591 artist-track relationships
# Processed 682000 out of 7716591 artist-track relationships
# Processed 683000 out of 7716591 artist-track relationships
# Processed 684000 out of 7716591 artist-track relationships
# Processed 685000 out of 7716591 artist-track relationships
# Processed 686000 out of 7716591 artist-track relationships
# Processed 687000 out of 7716591 artist-track relationships
# Processed 688000 out of 7716591 artist-track relationships
# Processed 689000 out of 7716591 artist-track relationships
# Processed 690000 out of 7716591 artist-track relationships
# Processed 691000 out of 7716591 artist-track relationships
# Processed 692000 out of 7716591 artist-track relationships
# Processed 693000 out of 7716591 artist-track relationships
# Processed 694000 out of 7716591 artist-track relationships
# Processed 695000 out of 7716591 artist-track relationships
# Processed 696000 out of 7716591 artist-track relationships
# Processed 697000 out of 7716591 artist-track relationships
# Processed 698000 out of 7716591 artist-track relationships
# Processed 699000 out of 7716591 artist-track relationships
# Processed 700000 out of 7716591 artist-track relationships
# Processed 701000 out of 7716591 artist-track relationships
# Processed 702000 out of 7716591 artist-track relationships
# Processed 703000 out of 7716591 artist-track relationships
# Processed 704000 out of 7716591 artist-track relationships
# Processed 705000 out of 7716591 artist-track relationships
# Processed 706000 out of 7716591 artist-track relationships
# Processed 707000 out of 7716591 artist-track relationships
# Processed 708000 out of 7716591 artist-track relationships
# Processed 709000 out of 7716591 artist-track relationships
# Processed 710000 out of 7716591 artist-track relationships
# Processed 711000 out of 7716591 artist-track relationships
# Processed 712000 out of 7716591 artist-track relationships
# Processed 713000 out of 7716591 artist-track relationships
# Processed 714000 out of 7716591 artist-track relationships
# Processed 715000 out of 7716591 artist-track relationships
# Processed 716000 out of 7716591 artist-track relationships
# Processed 717000 out of 7716591 artist-track relationships
# Processed 718000 out of 7716591 artist-track relationships
# Processed 719000 out of 7716591 artist-track relationships
# Processed 720000 out of 7716591 artist-track relationships
# Processed 721000 out of 7716591 artist-track relationships
# Processed 722000 out of 7716591 artist-track relationships
# Processed 723000 out of 7716591 artist-track relationships
# Processed 724000 out of 7716591 artist-track relationships
# Processed 725000 out of 7716591 artist-track relationships
# Processed 726000 out of 7716591 artist-track relationships
# Processed 727000 out of 7716591 artist-track relationships
# Processed 728000 out of 7716591 artist-track relationships
# Processed 729000 out of 7716591 artist-track relationships
# Processed 730000 out of 7716591 artist-track relationships
# Processed 731000 out of 7716591 artist-track relationships
# Processed 732000 out of 7716591 artist-track relationships
# Processed 733000 out of 7716591 artist-track relationships
# Processed 734000 out of 7716591 artist-track relationships
# Processed 735000 out of 7716591 artist-track relationships
# Processed 736000 out of 7716591 artist-track relationships
# Processed 737000 out of 7716591 artist-track relationships
# Processed 738000 out of 7716591 artist-track relationships
# Processed 739000 out of 7716591 artist-track relationships
# Processed 740000 out of 7716591 artist-track relationships
# Processed 741000 out of 7716591 artist-track relationships
# Processed 742000 out of 7716591 artist-track relationships
# Processed 743000 out of 7716591 artist-track relationships
# Processed 744000 out of 7716591 artist-track relationships
# Processed 745000 out of 7716591 artist-track relationships
# Processed 746000 out of 7716591 artist-track relationships
# Processed 747000 out of 7716591 artist-track relationships
# Processed 748000 out of 7716591 artist-track relationships
# Processed 749000 out of 7716591 artist-track relationships
# Processed 750000 out of 7716591 artist-track relationships
# Processed 751000 out of 7716591 artist-track relationships
# Processed 752000 out of 7716591 artist-track relationships
# Processed 753000 out of 7716591 artist-track relationships
# Processed 754000 out of 7716591 artist-track relationships
# Processed 755000 out of 7716591 artist-track relationships
# Processed 756000 out of 7716591 artist-track relationships
# Processed 757000 out of 7716591 artist-track relationships
# Processed 758000 out of 7716591 artist-track relationships
# Processed 759000 out of 7716591 artist-track relationships
# Processed 760000 out of 7716591 artist-track relationships
# Processed 761000 out of 7716591 artist-track relationships
# Processed 762000 out of 7716591 artist-track relationships
# Processed 763000 out of 7716591 artist-track relationships
# Processed 764000 out of 7716591 artist-track relationships
# Processed 765000 out of 7716591 artist-track relationships
# Processed 766000 out of 7716591 artist-track relationships
# Processed 767000 out of 7716591 artist-track relationships
# Processed 768000 out of 7716591 artist-track relationships
# Processed 769000 out of 7716591 artist-track relationships
# Processed 770000 out of 7716591 artist-track relationships
# Processed 771000 out of 7716591 artist-track relationships
# Processed 772000 out of 7716591 artist-track relationships
# Processed 773000 out of 7716591 artist-track relationships
# Processed 774000 out of 7716591 artist-track relationships
# Processed 775000 out of 7716591 artist-track relationships
# Processed 776000 out of 7716591 artist-track relationships
# Processed 777000 out of 7716591 artist-track relationships
# Processed 778000 out of 7716591 artist-track relationships
# Processed 779000 out of 7716591 artist-track relationships
# Processed 780000 out of 7716591 artist-track relationships
# Processed 781000 out of 7716591 artist-track relationships
# Processed 782000 out of 7716591 artist-track relationships
# Processed 783000 out of 7716591 artist-track relationships
# Processed 784000 out of 7716591 artist-track relationships
# Processed 785000 out of 7716591 artist-track relationships
# Processed 786000 out of 7716591 artist-track relationships
# Processed 787000 out of 7716591 artist-track relationships
# Processed 788000 out of 7716591 artist-track relationships
# Processed 789000 out of 7716591 artist-track relationships
# Processed 790000 out of 7716591 artist-track relationships
# Processed 791000 out of 7716591 artist-track relationships
# Processed 792000 out of 7716591 artist-track relationships
# Processed 793000 out of 7716591 artist-track relationships
# Processed 794000 out of 7716591 artist-track relationships
# Processed 795000 out of 7716591 artist-track relationships
# Processed 796000 out of 7716591 artist-track relationships
# Processed 797000 out of 7716591 artist-track relationships
# Processed 798000 out of 7716591 artist-track relationships
# Processed 799000 out of 7716591 artist-track relationships
# Processed 800000 out of 7716591 artist-track relationships
# Processed 801000 out of 7716591 artist-track relationships
# Processed 802000 out of 7716591 artist-track relationships
# Processed 803000 out of 7716591 artist-track relationships
# Processed 804000 out of 7716591 artist-track relationships
# Processed 805000 out of 7716591 artist-track relationships
# Processed 806000 out of 7716591 artist-track relationships
# Processed 807000 out of 7716591 artist-track relationships
# Processed 808000 out of 7716591 artist-track relationships
# Processed 809000 out of 7716591 artist-track relationships
# Processed 810000 out of 7716591 artist-track relationships
# Processed 811000 out of 7716591 artist-track relationships
# Processed 812000 out of 7716591 artist-track relationships
# Processed 813000 out of 7716591 artist-track relationships
# Processed 814000 out of 7716591 artist-track relationships
# ...
# Processed 7453000 out of 7716591 artist-track relationships
# Processed 7454000 out of 7716591 artist-track relationships
# Processed 7455000 out of 7716591 artist-track relationships
# Processed 7456000 out of 7716591 artist-track relationships
# Processed 7457000 out of 7716591 artist-track relationships
# Processed 7458000 out of 7716591 artist-track relationships
# Processed 7459000 out of 7716591 artist-track relationships
# Processed 7460000 out of 7716591 artist-track relationships
# Processed 7461000 out of 7716591 artist-track relationships
# Processed 7462000 out of 7716591 artist-track relationships
# Processed 7463000 out of 7716591 artist-track relationships
# Processed 7464000 out of 7716591 artist-track relationships
# Processed 7465000 out of 7716591 artist-track relationships
# Processed 7466000 out of 7716591 artist-track relationships
# Processed 7467000 out of 7716591 artist-track relationships
# Processed 7468000 out of 7716591 artist-track relationships
# Processed 7469000 out of 7716591 artist-track relationships
# Processed 7470000 out of 7716591 artist-track relationships
# Processed 7471000 out of 7716591 artist-track relationships
# Processed 7472000 out of 7716591 artist-track relationships
# Processed 7473000 out of 7716591 artist-track relationships
# Processed 7474000 out of 7716591 artist-track relationships
# Processed 7475000 out of 7716591 artist-track relationships
# Processed 7476000 out of 7716591 artist-track relationships
# Processed 7477000 out of 7716591 artist-track relationships
# Processed 7478000 out of 7716591 artist-track relationships
# Processed 7479000 out of 7716591 artist-track relationships
# Processed 7480000 out of 7716591 artist-track relationships
# Processed 7481000 out of 7716591 artist-track relationships
# Processed 7482000 out of 7716591 artist-track relationships
# Processed 7483000 out of 7716591 artist-track relationships
# Processed 7484000 out of 7716591 artist-track relationships
# Processed 7485000 out of 7716591 artist-track relationships
# Processed 7486000 out of 7716591 artist-track relationships
# Processed 7487000 out of 7716591 artist-track relationships
# Processed 7488000 out of 7716591 artist-track relationships
# Processed 7489000 out of 7716591 artist-track relationships
# Processed 7490000 out of 7716591 artist-track relationships
# Processed 7491000 out of 7716591 artist-track relationships
# Processed 7492000 out of 7716591 artist-track relationships
# Processed 7493000 out of 7716591 artist-track relationships
# Processed 7494000 out of 7716591 artist-track relationships
# Processed 7495000 out of 7716591 artist-track relationships
# Processed 7496000 out of 7716591 artist-track relationships
# Processed 7497000 out of 7716591 artist-track relationships
# Processed 7498000 out of 7716591 artist-track relationships
# Processed 7499000 out of 7716591 artist-track relationships
# Processed 7500000 out of 7716591 artist-track relationships
# Processed 7501000 out of 7716591 artist-track relationships
# Processed 7502000 out of 7716591 artist-track relationships
# Processed 7503000 out of 7716591 artist-track relationships
# Processed 7504000 out of 7716591 artist-track relationships
# Processed 7505000 out of 7716591 artist-track relationships
# Processed 7506000 out of 7716591 artist-track relationships
# Processed 7507000 out of 7716591 artist-track relationships
# Processed 7508000 out of 7716591 artist-track relationships
# Processed 7509000 out of 7716591 artist-track relationships
# Processed 7510000 out of 7716591 artist-track relationships
# Processed 7511000 out of 7716591 artist-track relationships
# Processed 7512000 out of 7716591 artist-track relationships
# Processed 7513000 out of 7716591 artist-track relationships
# Processed 7514000 out of 7716591 artist-track relationships
# Processed 7515000 out of 7716591 artist-track relationships
# Processed 7516000 out of 7716591 artist-track relationships
# Processed 7517000 out of 7716591 artist-track relationships
# Processed 7518000 out of 7716591 artist-track relationships
# Processed 7519000 out of 7716591 artist-track relationships
# Processed 7520000 out of 7716591 artist-track relationships
# Processed 7521000 out of 7716591 artist-track relationships
# Processed 7522000 out of 7716591 artist-track relationships
# Processed 7523000 out of 7716591 artist-track relationships
# Processed 7524000 out of 7716591 artist-track relationships
# Processed 7525000 out of 7716591 artist-track relationships
# Processed 7526000 out of 7716591 artist-track relationships
# Processed 7527000 out of 7716591 artist-track relationships
# Processed 7528000 out of 7716591 artist-track relationships
# Processed 7529000 out of 7716591 artist-track relationships
# Processed 7530000 out of 7716591 artist-track relationships
# Processed 7531000 out of 7716591 artist-track relationships
# Processed 7532000 out of 7716591 artist-track relationships
# Processed 7533000 out of 7716591 artist-track relationships
# Processed 7534000 out of 7716591 artist-track relationships
# Processed 7535000 out of 7716591 artist-track relationships
# Processed 7536000 out of 7716591 artist-track relationships
# Processed 7537000 out of 7716591 artist-track relationships
# Processed 7538000 out of 7716591 artist-track relationships
# Processed 7539000 out of 7716591 artist-track relationships
# Processed 7540000 out of 7716591 artist-track relationships
# Processed 7541000 out of 7716591 artist-track relationships
# Processed 7542000 out of 7716591 artist-track relationships
# Processed 7543000 out of 7716591 artist-track relationships
# Processed 7544000 out of 7716591 artist-track relationships
# Processed 7545000 out of 7716591 artist-track relationships
# Processed 7546000 out of 7716591 artist-track relationships
# Processed 7547000 out of 7716591 artist-track relationships
# Processed 7548000 out of 7716591 artist-track relationships
# Processed 7549000 out of 7716591 artist-track relationships
# Processed 7550000 out of 7716591 artist-track relationships
# Processed 7551000 out of 7716591 artist-track relationships
# Processed 7552000 out of 7716591 artist-track relationships
# Processed 7553000 out of 7716591 artist-track relationships
# Processed 7554000 out of 7716591 artist-track relationships
# Processed 7555000 out of 7716591 artist-track relationships
# Processed 7556000 out of 7716591 artist-track relationships
# Processed 7557000 out of 7716591 artist-track relationships
# Processed 7558000 out of 7716591 artist-track relationships
# Processed 7559000 out of 7716591 artist-track relationships
# Processed 7560000 out of 7716591 artist-track relationships
# Processed 7561000 out of 7716591 artist-track relationships
# Processed 7562000 out of 7716591 artist-track relationships
# Processed 7563000 out of 7716591 artist-track relationships
# Processed 7564000 out of 7716591 artist-track relationships
# Processed 7565000 out of 7716591 artist-track relationships
# Processed 7566000 out of 7716591 artist-track relationships
# Processed 7567000 out of 7716591 artist-track relationships
# Processed 7568000 out of 7716591 artist-track relationships
# Processed 7569000 out of 7716591 artist-track relationships
# Processed 7570000 out of 7716591 artist-track relationships
# Processed 7571000 out of 7716591 artist-track relationships
# Processed 7572000 out of 7716591 artist-track relationships
# Processed 7573000 out of 7716591 artist-track relationships
# Processed 7574000 out of 7716591 artist-track relationships
# Processed 7575000 out of 7716591 artist-track relationships
# Processed 7576000 out of 7716591 artist-track relationships
# Processed 7577000 out of 7716591 artist-track relationships
# Processed 7578000 out of 7716591 artist-track relationships
# Processed 7579000 out of 7716591 artist-track relationships
# Processed 7580000 out of 7716591 artist-track relationships
# Processed 7581000 out of 7716591 artist-track relationships
# Processed 7582000 out of 7716591 artist-track relationships
# Processed 7583000 out of 7716591 artist-track relationships
# Processed 7584000 out of 7716591 artist-track relationships
# Processed 7585000 out of 7716591 artist-track relationships
# Processed 7586000 out of 7716591 artist-track relationships
# Processed 7587000 out of 7716591 artist-track relationships
# Processed 7588000 out of 7716591 artist-track relationships
# Processed 7589000 out of 7716591 artist-track relationships
# Processed 7590000 out of 7716591 artist-track relationships
# Processed 7591000 out of 7716591 artist-track relationships
# Processed 7592000 out of 7716591 artist-track relationships
# Processed 7593000 out of 7716591 artist-track relationships
# Processed 7594000 out of 7716591 artist-track relationships
# Processed 7595000 out of 7716591 artist-track relationships
# Processed 7596000 out of 7716591 artist-track relationships
# Processed 7597000 out of 7716591 artist-track relationships
# Processed 7598000 out of 7716591 artist-track relationships
# Processed 7599000 out of 7716591 artist-track relationships
# Processed 7600000 out of 7716591 artist-track relationships
# Processed 7601000 out of 7716591 artist-track relationships
# Processed 7602000 out of 7716591 artist-track relationships
# Processed 7603000 out of 7716591 artist-track relationships
# Processed 7604000 out of 7716591 artist-track relationships
# Processed 7605000 out of 7716591 artist-track relationships
# Processed 7606000 out of 7716591 artist-track relationships
# Processed 7607000 out of 7716591 artist-track relationships
# Processed 7608000 out of 7716591 artist-track relationships
# Processed 7609000 out of 7716591 artist-track relationships
# Processed 7610000 out of 7716591 artist-track relationships
# Processed 7611000 out of 7716591 artist-track relationships
# Processed 7612000 out of 7716591 artist-track relationships
# Processed 7613000 out of 7716591 artist-track relationships
# Processed 7614000 out of 7716591 artist-track relationships
# Processed 7615000 out of 7716591 artist-track relationships
# Processed 7616000 out of 7716591 artist-track relationships
# Processed 7617000 out of 7716591 artist-track relationships
# Processed 7618000 out of 7716591 artist-track relationships
# Processed 7619000 out of 7716591 artist-track relationships
# Processed 7620000 out of 7716591 artist-track relationships
# Processed 7621000 out of 7716591 artist-track relationships
# Processed 7622000 out of 7716591 artist-track relationships
# Processed 7623000 out of 7716591 artist-track relationships
# Processed 7624000 out of 7716591 artist-track relationships
# Processed 7625000 out of 7716591 artist-track relationships
# Processed 7626000 out of 7716591 artist-track relationships
# Processed 7627000 out of 7716591 artist-track relationships
# Processed 7628000 out of 7716591 artist-track relationships
# Processed 7629000 out of 7716591 artist-track relationships
# Processed 7630000 out of 7716591 artist-track relationships
# Processed 7631000 out of 7716591 artist-track relationships
# Processed 7632000 out of 7716591 artist-track relationships
# Processed 7633000 out of 7716591 artist-track relationships
# Processed 7634000 out of 7716591 artist-track relationships
# Processed 7635000 out of 7716591 artist-track relationships
# Processed 7636000 out of 7716591 artist-track relationships
# Processed 7637000 out of 7716591 artist-track relationships
# Processed 7638000 out of 7716591 artist-track relationships
# Processed 7639000 out of 7716591 artist-track relationships
# Processed 7640000 out of 7716591 artist-track relationships
# Processed 7641000 out of 7716591 artist-track relationships
# Processed 7642000 out of 7716591 artist-track relationships
# Processed 7643000 out of 7716591 artist-track relationships
# Processed 7644000 out of 7716591 artist-track relationships
# Processed 7645000 out of 7716591 artist-track relationships
# Processed 7646000 out of 7716591 artist-track relationships
# Processed 7647000 out of 7716591 artist-track relationships
# Processed 7648000 out of 7716591 artist-track relationships
# Processed 7649000 out of 7716591 artist-track relationships
# Processed 7650000 out of 7716591 artist-track relationships
# Processed 7651000 out of 7716591 artist-track relationships
# Processed 7652000 out of 7716591 artist-track relationships
# Processed 7653000 out of 7716591 artist-track relationships
# Processed 7654000 out of 7716591 artist-track relationships
# Processed 7655000 out of 7716591 artist-track relationships
# Processed 7656000 out of 7716591 artist-track relationships
# Processed 7657000 out of 7716591 artist-track relationships
# Processed 7658000 out of 7716591 artist-track relationships
# Processed 7659000 out of 7716591 artist-track relationships
# Processed 7660000 out of 7716591 artist-track relationships
# Processed 7661000 out of 7716591 artist-track relationships
# Processed 7662000 out of 7716591 artist-track relationships
# Processed 7663000 out of 7716591 artist-track relationships
# Processed 7664000 out of 7716591 artist-track relationships
# Processed 7665000 out of 7716591 artist-track relationships
# Processed 7666000 out of 7716591 artist-track relationships
# Processed 7667000 out of 7716591 artist-track relationships
# Processed 7668000 out of 7716591 artist-track relationships
# Processed 7669000 out of 7716591 artist-track relationships
# Processed 7670000 out of 7716591 artist-track relationships
# Processed 7671000 out of 7716591 artist-track relationships
# Processed 7672000 out of 7716591 artist-track relationships
# Processed 7673000 out of 7716591 artist-track relationships
# Processed 7674000 out of 7716591 artist-track relationships
# Processed 7675000 out of 7716591 artist-track relationships
# Processed 7676000 out of 7716591 artist-track relationships
# Processed 7677000 out of 7716591 artist-track relationships
# Processed 7678000 out of 7716591 artist-track relationships
# Processed 7679000 out of 7716591 artist-track relationships
# Processed 7680000 out of 7716591 artist-track relationships
# Processed 7681000 out of 7716591 artist-track relationships
# Processed 7682000 out of 7716591 artist-track relationships
# Processed 7683000 out of 7716591 artist-track relationships
# Processed 7684000 out of 7716591 artist-track relationships
# Processed 7685000 out of 7716591 artist-track relationships
# Processed 7686000 out of 7716591 artist-track relationships
# Processed 7687000 out of 7716591 artist-track relationships
# Processed 7688000 out of 7716591 artist-track relationships
# Processed 7689000 out of 7716591 artist-track relationships
# Processed 7690000 out of 7716591 artist-track relationships
# Processed 7691000 out of 7716591 artist-track relationships
# Processed 7692000 out of 7716591 artist-track relationships
# Processed 7693000 out of 7716591 artist-track relationships
# Processed 7694000 out of 7716591 artist-track relationships
# Processed 7695000 out of 7716591 artist-track relationships
# Processed 7696000 out of 7716591 artist-track relationships
# Processed 7697000 out of 7716591 artist-track relationships
# Processed 7698000 out of 7716591 artist-track relationships
# Processed 7699000 out of 7716591 artist-track relationships
# Processed 7700000 out of 7716591 artist-track relationships
# Processed 7701000 out of 7716591 artist-track relationships
# Processed 7702000 out of 7716591 artist-track relationships
# Processed 7703000 out of 7716591 artist-track relationships
# Processed 7704000 out of 7716591 artist-track relationships
# Processed 7705000 out of 7716591 artist-track relationships
# Processed 7706000 out of 7716591 artist-track relationships
# Processed 7707000 out of 7716591 artist-track relationships
# Processed 7708000 out of 7716591 artist-track relationships
# Processed 7709000 out of 7716591 artist-track relationships
# Processed 7710000 out of 7716591 artist-track relationships
# Processed 7711000 out of 7716591 artist-track relationships
# Processed 7712000 out of 7716591 artist-track relationships
# Processed 7713000 out of 7716591 artist-track relationships
# Processed 7714000 out of 7716591 artist-track relationships
# Processed 7715000 out of 7716591 artist-track relationships
# Processed 7716000 out of 7716591 artist-track relationships
# Processed 7716591 out of 7716591 artist-track relationships
# Artist-track relationships imported successfully
# All data imported successfully!

# %%
def import_artist_releases(engine):
    """Import artist-release relationships with parameter binding"""
    try:
        print("Importing artist-release relationships...")
        df = pd.read_csv('sp_artist_release.csv')
        df = clean_dataframe(df)
        df['updated_on'] = pd.to_datetime(df['updated_on']).dt.strftime('%Y-%m-%d %H:%M:%S')
        
        chunk_size = 10000
        total_rows = len(df)
        
        # First connection to disable foreign key checks
        with engine.connect() as conn1:
            conn1.execute(text("SET FOREIGN_KEY_CHECKS=0"))
        
        # Second connection for data import
        with engine.connect() as conn2:
            with conn2.begin():
                for i in range(0, total_rows, chunk_size):
                    chunk = df.iloc[i:i + chunk_size]
                    
                    records = [{
                        'release_id': str(row['release_id']),
                        'artist_id': str(row['artist_id']),
                        'updated_on': row['updated_on']
                    } for _, row in chunk.iterrows()]
                    
                    insert_stmt = text("""
                        INSERT IGNORE INTO artist_release (release_id, artist_id, updated_on)
                        VALUES (:release_id, :artist_id, :updated_on)
                    """)
                    
                    conn2.execute(insert_stmt, records)
                    print(f"Processed {min(i + chunk_size, total_rows)} out of {total_rows} artist-release relationships")
        
        # Third connection to re-enable foreign key checks
        with engine.connect() as conn3:
            conn3.execute(text("SET FOREIGN_KEY_CHECKS=1"))
            
        print("Artist-release relationships imported successfully")
                
    except Exception as e:
        print(f"Error importing artist-release relationships: {str(e)}")
        raise

# %%
def main():
    """Main function to create schema and import data"""
    try:
        engine = create_mysql_engine()
        
        # Import data table by table
        import_artist_releases(engine)
        
        print("All data imported successfully!")
    except Exception as e:
        print(f"Error in main execution: {str(e)}")
        raise

if __name__ == "__main__":
    main()
# Out:
# Importing artist-release relationships...
# Processed 10000 out of 3969489 artist-release relationships
# Processed 20000 out of 3969489 artist-release relationships
# Processed 30000 out of 3969489 artist-release relationships
# Processed 40000 out of 3969489 artist-release relationships
# Processed 50000 out of 3969489 artist-release relationships
# Processed 60000 out of 3969489 artist-release relationships
# Processed 70000 out of 3969489 artist-release relationships
# Processed 80000 out of 3969489 artist-release relationships
# Processed 90000 out of 3969489 artist-release relationships
# Processed 100000 out of 3969489 artist-release relationships
# Processed 110000 out of 3969489 artist-release relationships
# Processed 120000 out of 3969489 artist-release relationships
# Processed 130000 out of 3969489 artist-release relationships
# Processed 140000 out of 3969489 artist-release relationships
# Processed 150000 out of 3969489 artist-release relationships
# Processed 160000 out of 3969489 artist-release relationships
# Processed 170000 out of 3969489 artist-release relationships
# Processed 180000 out of 3969489 artist-release relationships
# Processed 190000 out of 3969489 artist-release relationships
# Processed 200000 out of 3969489 artist-release relationships
# Processed 210000 out of 3969489 artist-release relationships
# Processed 220000 out of 3969489 artist-release relationships
# Processed 230000 out of 3969489 artist-release relationships
# Processed 240000 out of 3969489 artist-release relationships
# Processed 250000 out of 3969489 artist-release relationships
# Processed 260000 out of 3969489 artist-release relationships
# Processed 270000 out of 3969489 artist-release relationships
# Processed 280000 out of 3969489 artist-release relationships
# Processed 290000 out of 3969489 artist-release relationships
# Processed 300000 out of 3969489 artist-release relationships
# Processed 310000 out of 3969489 artist-release relationships
# Processed 320000 out of 3969489 artist-release relationships
# Processed 330000 out of 3969489 artist-release relationships
# Processed 340000 out of 3969489 artist-release relationships
# Processed 350000 out of 3969489 artist-release relationships
# Processed 360000 out of 3969489 artist-release relationships
# Processed 370000 out of 3969489 artist-release relationships
# Processed 380000 out of 3969489 artist-release relationships
# Processed 390000 out of 3969489 artist-release relationships
# Processed 400000 out of 3969489 artist-release relationships
# Processed 410000 out of 3969489 artist-release relationships
# Processed 420000 out of 3969489 artist-release relationships
# Processed 430000 out of 3969489 artist-release relationships
# Processed 440000 out of 3969489 artist-release relationships
# Processed 450000 out of 3969489 artist-release relationships
# Processed 460000 out of 3969489 artist-release relationships
# Processed 470000 out of 3969489 artist-release relationships
# Processed 480000 out of 3969489 artist-release relationships
# Processed 490000 out of 3969489 artist-release relationships
# Processed 500000 out of 3969489 artist-release relationships
# Processed 510000 out of 3969489 artist-release relationships
# Processed 520000 out of 3969489 artist-release relationships
# Processed 530000 out of 3969489 artist-release relationships
# Processed 540000 out of 3969489 artist-release relationships
# Processed 550000 out of 3969489 artist-release relationships
# Processed 560000 out of 3969489 artist-release relationships
# Processed 570000 out of 3969489 artist-release relationships
# Processed 580000 out of 3969489 artist-release relationships
# Processed 590000 out of 3969489 artist-release relationships
# Processed 600000 out of 3969489 artist-release relationships
# Processed 610000 out of 3969489 artist-release relationships
# Processed 620000 out of 3969489 artist-release relationships
# Processed 630000 out of 3969489 artist-release relationships
# Processed 640000 out of 3969489 artist-release relationships
# Processed 650000 out of 3969489 artist-release relationships
# Processed 660000 out of 3969489 artist-release relationships
# Processed 670000 out of 3969489 artist-release relationships
# Processed 680000 out of 3969489 artist-release relationships
# Processed 690000 out of 3969489 artist-release relationships
# Processed 700000 out of 3969489 artist-release relationships
# Processed 710000 out of 3969489 artist-release relationships
# Processed 720000 out of 3969489 artist-release relationships
# Processed 730000 out of 3969489 artist-release relationships
# Processed 740000 out of 3969489 artist-release relationships
# Processed 750000 out of 3969489 artist-release relationships
# Processed 760000 out of 3969489 artist-release relationships
# Processed 770000 out of 3969489 artist-release relationships
# Processed 780000 out of 3969489 artist-release relationships
# Processed 790000 out of 3969489 artist-release relationships
# Processed 800000 out of 3969489 artist-release relationships
# Processed 810000 out of 3969489 artist-release relationships
# Processed 820000 out of 3969489 artist-release relationships
# Processed 830000 out of 3969489 artist-release relationships
# Processed 840000 out of 3969489 artist-release relationships
# Processed 850000 out of 3969489 artist-release relationships
# Processed 860000 out of 3969489 artist-release relationships
# Processed 870000 out of 3969489 artist-release relationships
# Processed 880000 out of 3969489 artist-release relationships
# Processed 890000 out of 3969489 artist-release relationships
# Processed 900000 out of 3969489 artist-release relationships
# Processed 910000 out of 3969489 artist-release relationships
# Processed 920000 out of 3969489 artist-release relationships
# Processed 930000 out of 3969489 artist-release relationships
# Processed 940000 out of 3969489 artist-release relationships
# Processed 950000 out of 3969489 artist-release relationships
# Processed 960000 out of 3969489 artist-release relationships
# Processed 970000 out of 3969489 artist-release relationships
# Processed 980000 out of 3969489 artist-release relationships
# Processed 990000 out of 3969489 artist-release relationships
# Processed 1000000 out of 3969489 artist-release relationships
# Processed 1010000 out of 3969489 artist-release relationships
# Processed 1020000 out of 3969489 artist-release relationships
# Processed 1030000 out of 3969489 artist-release relationships
# Processed 1040000 out of 3969489 artist-release relationships
# Processed 1050000 out of 3969489 artist-release relationships
# Processed 1060000 out of 3969489 artist-release relationships
# Processed 1070000 out of 3969489 artist-release relationships
# Processed 1080000 out of 3969489 artist-release relationships
# Processed 1090000 out of 3969489 artist-release relationships
# Processed 1100000 out of 3969489 artist-release relationships
# Processed 1110000 out of 3969489 artist-release relationships
# Processed 1120000 out of 3969489 artist-release relationships
# Processed 1130000 out of 3969489 artist-release relationships
# Processed 1140000 out of 3969489 artist-release relationships
# Processed 1150000 out of 3969489 artist-release relationships
# Processed 1160000 out of 3969489 artist-release relationships
# Processed 1170000 out of 3969489 artist-release relationships
# Processed 1180000 out of 3969489 artist-release relationships
# Processed 1190000 out of 3969489 artist-release relationships
# Processed 1200000 out of 3969489 artist-release relationships
# Processed 1210000 out of 3969489 artist-release relationships
# Processed 1220000 out of 3969489 artist-release relationships
# Processed 1230000 out of 3969489 artist-release relationships
# Processed 1240000 out of 3969489 artist-release relationships
# Processed 1250000 out of 3969489 artist-release relationships
# Processed 1260000 out of 3969489 artist-release relationships
# Processed 1270000 out of 3969489 artist-release relationships
# Processed 1280000 out of 3969489 artist-release relationships
# Processed 1290000 out of 3969489 artist-release relationships
# Processed 1300000 out of 3969489 artist-release relationships
# Processed 1310000 out of 3969489 artist-release relationships
# Processed 1320000 out of 3969489 artist-release relationships
# Processed 1330000 out of 3969489 artist-release relationships
# Processed 1340000 out of 3969489 artist-release relationships
# Processed 1350000 out of 3969489 artist-release relationships
# Processed 1360000 out of 3969489 artist-release relationships
# Processed 1370000 out of 3969489 artist-release relationships
# Processed 1380000 out of 3969489 artist-release relationships
# Processed 1390000 out of 3969489 artist-release relationships
# Processed 1400000 out of 3969489 artist-release relationships
# Processed 1410000 out of 3969489 artist-release relationships
# Processed 1420000 out of 3969489 artist-release relationships
# Processed 1430000 out of 3969489 artist-release relationships
# Processed 1440000 out of 3969489 artist-release relationships
# Processed 1450000 out of 3969489 artist-release relationships
# Processed 1460000 out of 3969489 artist-release relationships
# Processed 1470000 out of 3969489 artist-release relationships
# Processed 1480000 out of 3969489 artist-release relationships
# Processed 1490000 out of 3969489 artist-release relationships
# Processed 1500000 out of 3969489 artist-release relationships
# Processed 1510000 out of 3969489 artist-release relationships
# Processed 1520000 out of 3969489 artist-release relationships
# Processed 1530000 out of 3969489 artist-release relationships
# Processed 1540000 out of 3969489 artist-release relationships
# Processed 1550000 out of 3969489 artist-release relationships
# Processed 1560000 out of 3969489 artist-release relationships
# Processed 1570000 out of 3969489 artist-release relationships
# Processed 1580000 out of 3969489 artist-release relationships
# Processed 1590000 out of 3969489 artist-release relationships
# Processed 1600000 out of 3969489 artist-release relationships
# Processed 1610000 out of 3969489 artist-release relationships
# Processed 1620000 out of 3969489 artist-release relationships
# Processed 1630000 out of 3969489 artist-release relationships
# Processed 1640000 out of 3969489 artist-release relationships
# Processed 1650000 out of 3969489 artist-release relationships
# Processed 1660000 out of 3969489 artist-release relationships
# Processed 1670000 out of 3969489 artist-release relationships
# Processed 1680000 out of 3969489 artist-release relationships
# Processed 1690000 out of 3969489 artist-release relationships
# Processed 1700000 out of 3969489 artist-release relationships
# Processed 1710000 out of 3969489 artist-release relationships
# Processed 1720000 out of 3969489 artist-release relationships
# Processed 1730000 out of 3969489 artist-release relationships
# Processed 1740000 out of 3969489 artist-release relationships
# Processed 1750000 out of 3969489 artist-release relationships
# Processed 1760000 out of 3969489 artist-release relationships
# Processed 1770000 out of 3969489 artist-release relationships
# Processed 1780000 out of 3969489 artist-release relationships
# Processed 1790000 out of 3969489 artist-release relationships
# Processed 1800000 out of 3969489 artist-release relationships
# Processed 1810000 out of 3969489 artist-release relationships
# Processed 1820000 out of 3969489 artist-release relationships
# Processed 1830000 out of 3969489 artist-release relationships
# Processed 1840000 out of 3969489 artist-release relationships
# Processed 1850000 out of 3969489 artist-release relationships
# Processed 1860000 out of 3969489 artist-release relationships
# Processed 1870000 out of 3969489 artist-release relationships
# Processed 1880000 out of 3969489 artist-release relationships
# Processed 1890000 out of 3969489 artist-release relationships
# Processed 1900000 out of 3969489 artist-release relationships
# Processed 1910000 out of 3969489 artist-release relationships
# Processed 1920000 out of 3969489 artist-release relationships
# Processed 1930000 out of 3969489 artist-release relationships
# Processed 1940000 out of 3969489 artist-release relationships
# Processed 1950000 out of 3969489 artist-release relationships
# Processed 1960000 out of 3969489 artist-release relationships
# Processed 1970000 out of 3969489 artist-release relationships
# Processed 1980000 out of 3969489 artist-release relationships
# Processed 1990000 out of 3969489 artist-release relationships
# Processed 2000000 out of 3969489 artist-release relationships
# Processed 2010000 out of 3969489 artist-release relationships
# Processed 2020000 out of 3969489 artist-release relationships
# Processed 2030000 out of 3969489 artist-release relationships
# Processed 2040000 out of 3969489 artist-release relationships
# Processed 2050000 out of 3969489 artist-release relationships
# Processed 2060000 out of 3969489 artist-release relationships
# Processed 2070000 out of 3969489 artist-release relationships
# Processed 2080000 out of 3969489 artist-release relationships
# Processed 2090000 out of 3969489 artist-release relationships
# Processed 2100000 out of 3969489 artist-release relationships
# Processed 2110000 out of 3969489 artist-release relationships
# Processed 2120000 out of 3969489 artist-release relationships
# Processed 2130000 out of 3969489 artist-release relationships
# Processed 2140000 out of 3969489 artist-release relationships
# Processed 2150000 out of 3969489 artist-release relationships
# Processed 2160000 out of 3969489 artist-release relationships
# Processed 2170000 out of 3969489 artist-release relationships
# Processed 2180000 out of 3969489 artist-release relationships
# Processed 2190000 out of 3969489 artist-release relationships
# Processed 2200000 out of 3969489 artist-release relationships
# Processed 2210000 out of 3969489 artist-release relationships
# Processed 2220000 out of 3969489 artist-release relationships
# Processed 2230000 out of 3969489 artist-release relationships
# Processed 2240000 out of 3969489 artist-release relationships
# Processed 2250000 out of 3969489 artist-release relationships
# Processed 2260000 out of 3969489 artist-release relationships
# Processed 2270000 out of 3969489 artist-release relationships
# Processed 2280000 out of 3969489 artist-release relationships
# Processed 2290000 out of 3969489 artist-release relationships
# Processed 2300000 out of 3969489 artist-release relationships
# Processed 2310000 out of 3969489 artist-release relationships
# Processed 2320000 out of 3969489 artist-release relationships
# Processed 2330000 out of 3969489 artist-release relationships
# Processed 2340000 out of 3969489 artist-release relationships
# Processed 2350000 out of 3969489 artist-release relationships
# Processed 2360000 out of 3969489 artist-release relationships
# Processed 2370000 out of 3969489 artist-release relationships
# Processed 2380000 out of 3969489 artist-release relationships
# Processed 2390000 out of 3969489 artist-release relationships
# Processed 2400000 out of 3969489 artist-release relationships
# Processed 2410000 out of 3969489 artist-release relationships
# Processed 2420000 out of 3969489 artist-release relationships
# Processed 2430000 out of 3969489 artist-release relationships
# Processed 2440000 out of 3969489 artist-release relationships
# Processed 2450000 out of 3969489 artist-release relationships
# Processed 2460000 out of 3969489 artist-release relationships
# Processed 2470000 out of 3969489 artist-release relationships
# Processed 2480000 out of 3969489 artist-release relationships
# Processed 2490000 out of 3969489 artist-release relationships
# Processed 2500000 out of 3969489 artist-release relationships
# Processed 2510000 out of 3969489 artist-release relationships
# Processed 2520000 out of 3969489 artist-release relationships
# Processed 2530000 out of 3969489 artist-release relationships
# Processed 2540000 out of 3969489 artist-release relationships
# Processed 2550000 out of 3969489 artist-release relationships
# Processed 2560000 out of 3969489 artist-release relationships
# Processed 2570000 out of 3969489 artist-release relationships
# Processed 2580000 out of 3969489 artist-release relationships
# Processed 2590000 out of 3969489 artist-release relationships
# Processed 2600000 out of 3969489 artist-release relationships
# Processed 2610000 out of 3969489 artist-release relationships
# Processed 2620000 out of 3969489 artist-release relationships
# Processed 2630000 out of 3969489 artist-release relationships
# Processed 2640000 out of 3969489 artist-release relationships
# Processed 2650000 out of 3969489 artist-release relationships
# Processed 2660000 out of 3969489 artist-release relationships
# Processed 2670000 out of 3969489 artist-release relationships
# Processed 2680000 out of 3969489 artist-release relationships
# Processed 2690000 out of 3969489 artist-release relationships
# Processed 2700000 out of 3969489 artist-release relationships
# Processed 2710000 out of 3969489 artist-release relationships
# Processed 2720000 out of 3969489 artist-release relationships
# Processed 2730000 out of 3969489 artist-release relationships
# Processed 2740000 out of 3969489 artist-release relationships
# Processed 2750000 out of 3969489 artist-release relationships
# Processed 2760000 out of 3969489 artist-release relationships
# Processed 2770000 out of 3969489 artist-release relationships
# Processed 2780000 out of 3969489 artist-release relationships
# Processed 2790000 out of 3969489 artist-release relationships
# Processed 2800000 out of 3969489 artist-release relationships
# Processed 2810000 out of 3969489 artist-release relationships
# Processed 2820000 out of 3969489 artist-release relationships
# Processed 2830000 out of 3969489 artist-release relationships
# Processed 2840000 out of 3969489 artist-release relationships
# Processed 2850000 out of 3969489 artist-release relationships
# Processed 2860000 out of 3969489 artist-release relationships
# Processed 2870000 out of 3969489 artist-release relationships
# Processed 2880000 out of 3969489 artist-release relationships
# Processed 2890000 out of 3969489 artist-release relationships
# Processed 2900000 out of 3969489 artist-release relationships
# Processed 2910000 out of 3969489 artist-release relationships
# Processed 2920000 out of 3969489 artist-release relationships
# Processed 2930000 out of 3969489 artist-release relationships
# Processed 2940000 out of 3969489 artist-release relationships
# Processed 2950000 out of 3969489 artist-release relationships
# Processed 2960000 out of 3969489 artist-release relationships
# Processed 2970000 out of 3969489 artist-release relationships
# Processed 2980000 out of 3969489 artist-release relationships
# Processed 2990000 out of 3969489 artist-release relationships
# Processed 3000000 out of 3969489 artist-release relationships
# Processed 3010000 out of 3969489 artist-release relationships
# Processed 3020000 out of 3969489 artist-release relationships
# Processed 3030000 out of 3969489 artist-release relationships
# Processed 3040000 out of 3969489 artist-release relationships
# Processed 3050000 out of 3969489 artist-release relationships
# Processed 3060000 out of 3969489 artist-release relationships
# Processed 3070000 out of 3969489 artist-release relationships
# Processed 3080000 out of 3969489 artist-release relationships
# Processed 3090000 out of 3969489 artist-release relationships
# Processed 3100000 out of 3969489 artist-release relationships
# Processed 3110000 out of 3969489 artist-release relationships
# Processed 3120000 out of 3969489 artist-release relationships
# Processed 3130000 out of 3969489 artist-release relationships
# Processed 3140000 out of 3969489 artist-release relationships
# Processed 3150000 out of 3969489 artist-release relationships
# Processed 3160000 out of 3969489 artist-release relationships
# Processed 3170000 out of 3969489 artist-release relationships
# Processed 3180000 out of 3969489 artist-release relationships
# Processed 3190000 out of 3969489 artist-release relationships
# Processed 3200000 out of 3969489 artist-release relationships
# Processed 3210000 out of 3969489 artist-release relationships
# Processed 3220000 out of 3969489 artist-release relationships
# Processed 3230000 out of 3969489 artist-release relationships
# Processed 3240000 out of 3969489 artist-release relationships
# Processed 3250000 out of 3969489 artist-release relationships
# Processed 3260000 out of 3969489 artist-release relationships
# Processed 3270000 out of 3969489 artist-release relationships
# Processed 3280000 out of 3969489 artist-release relationships
# Processed 3290000 out of 3969489 artist-release relationships
# Processed 3300000 out of 3969489 artist-release relationships
# Processed 3310000 out of 3969489 artist-release relationships
# Processed 3320000 out of 3969489 artist-release relationships
# Processed 3330000 out of 3969489 artist-release relationships
# Processed 3340000 out of 3969489 artist-release relationships
# Processed 3350000 out of 3969489 artist-release relationships
# Processed 3360000 out of 3969489 artist-release relationships
# Processed 3370000 out of 3969489 artist-release relationships
# Processed 3380000 out of 3969489 artist-release relationships
# Processed 3390000 out of 3969489 artist-release relationships
# Processed 3400000 out of 3969489 artist-release relationships
# Processed 3410000 out of 3969489 artist-release relationships
# Processed 3420000 out of 3969489 artist-release relationships
# Processed 3430000 out of 3969489 artist-release relationships
# Processed 3440000 out of 3969489 artist-release relationships
# Processed 3450000 out of 3969489 artist-release relationships
# Processed 3460000 out of 3969489 artist-release relationships
# Processed 3470000 out of 3969489 artist-release relationships
# Processed 3480000 out of 3969489 artist-release relationships
# Processed 3490000 out of 3969489 artist-release relationships
# Processed 3500000 out of 3969489 artist-release relationships
# Processed 3510000 out of 3969489 artist-release relationships
# Processed 3520000 out of 3969489 artist-release relationships
# Processed 3530000 out of 3969489 artist-release relationships
# Processed 3540000 out of 3969489 artist-release relationships
# Processed 3550000 out of 3969489 artist-release relationships
# Processed 3560000 out of 3969489 artist-release relationships
# Processed 3570000 out of 3969489 artist-release relationships
# Processed 3580000 out of 3969489 artist-release relationships
# Processed 3590000 out of 3969489 artist-release relationships
# Processed 3600000 out of 3969489 artist-release relationships
# Processed 3610000 out of 3969489 artist-release relationships
# Processed 3620000 out of 3969489 artist-release relationships
# Processed 3630000 out of 3969489 artist-release relationships
# Processed 3640000 out of 3969489 artist-release relationships
# Processed 3650000 out of 3969489 artist-release relationships
# Processed 3660000 out of 3969489 artist-release relationships
# Processed 3670000 out of 3969489 artist-release relationships
# Processed 3680000 out of 3969489 artist-release relationships
# Processed 3690000 out of 3969489 artist-release relationships
# Processed 3700000 out of 3969489 artist-release relationships
# Processed 3710000 out of 3969489 artist-release relationships
# Processed 3720000 out of 3969489 artist-release relationships
# Processed 3730000 out of 3969489 artist-release relationships
# Processed 3740000 out of 3969489 artist-release relationships
# Processed 3750000 out of 3969489 artist-release relationships
# Processed 3760000 out of 3969489 artist-release relationships
# Processed 3770000 out of 3969489 artist-release relationships
# Processed 3780000 out of 3969489 artist-release relationships
# Processed 3790000 out of 3969489 artist-release relationships
# Processed 3800000 out of 3969489 artist-release relationships
# Processed 3810000 out of 3969489 artist-release relationships
# Processed 3820000 out of 3969489 artist-release relationships
# Processed 3830000 out of 3969489 artist-release relationships
# Processed 3840000 out of 3969489 artist-release relationships
# Processed 3850000 out of 3969489 artist-release relationships
# Processed 3860000 out of 3969489 artist-release relationships
# Processed 3870000 out of 3969489 artist-release relationships
# Processed 3880000 out of 3969489 artist-release relationships
# Processed 3890000 out of 3969489 artist-release relationships
# Processed 3900000 out of 3969489 artist-release relationships
# Processed 3910000 out of 3969489 artist-release relationships
# Processed 3920000 out of 3969489 artist-release relationships
# Processed 3930000 out of 3969489 artist-release relationships
# Processed 3940000 out of 3969489 artist-release relationships
# Processed 3950000 out of 3969489 artist-release relationships
# Processed 3960000 out of 3969489 artist-release relationships
# Processed 3969489 out of 3969489 artist-release relationships
# Artist-release relationships imported successfully
# All data imported successfully!

# %%
"""def main():
    "Main function to create schema and import data"
    try:
        engine = create_mysql_engine()
        
        # Import data table by table
        import_artists(engine)
        import_releases(engine)
        import_tracks(engine)
        import_audio_features(engine)
        import_artist_tracks(engine)
        import_artist_releases(engine)
        
        print("All data imported successfully!")
    except Exception as e:
        print(f"Error in main execution: {str(e)}")
        raise

if __name__ == "__main__":
    main()"""
# Out:
# Importing artists...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 20
#      17         raise
#      19 if __name__ == "__main__":
# ---> 20     main()
#
# Cell In[17], line 7, in main()
#       4 engine = create_mysql_engine()
#       6 # Import data table by table
# ----> 7 import_artists(engine)
#       8 import_releases(engine)
#       9 import_tracks(engine)
#
# Cell In[10], line 17, in import_artists(engine)
#      12     for _, row in df.iterrows():
#      13         insert_stmt = text("""
#      14             INSERT IGNORE INTO artist (artist_id, artist_name, updated_on)
#      15             VALUES (:artist_id, :artist_name, :updated_on)
#      16         """)
# ---> 17         conn.execute(insert_stmt, row.to_dict())
#      18     conn.commit()
#      19 print("Artists imported successfully")
#
# File c:\Users\olivi\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File c:\Users\olivi\anaconda3\Lib\site-packages\sqlalchemy\sql\elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File c:\Users\olivi\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File c:\Users\olivi\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File c:\Users\olivi\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File c:\Users\olivi\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2358, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2356     else:
#    2357         assert exc_info[1] is not None
# -> 2358         raise exc_info[1].with_traceback(exc_info[2])
#    2359 finally:
#    2360     del self._reentrant_error
#
# File c:\Users\olivi\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)
#    1978         context.executemany,
#    1979     )
#
# File c:\Users\olivi\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:941, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     940 def do_execute(self, cursor, statement, parameters, context=None):
# --> 941     cursor.execute(statement, parameters)
#
# File c:\Users\olivi\anaconda3\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File c:\Users\olivi\anaconda3\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# File c:\Users\olivi\anaconda3\Lib\site-packages\pymysql\connections.py:562, in Connection.query(self, sql, unbuffered)
#     560 if isinstance(sql, str):
#     561     sql = sql.encode(self.encoding, "surrogateescape")
# --> 562 self._execute_command(COMMAND.COM_QUERY, sql)
#     563 self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     564 return self._affected_rows
#
# File c:\Users\olivi\anaconda3\Lib\site-packages\pymysql\connections.py:864, in Connection._execute_command(self, command, sql)
#     862 prelude = struct.pack("<iB", packet_size, command)
#     863 packet = prelude + sql[: packet_size - 1]
# --> 864 self._write_bytes(packet)
#     865 if DEBUG:
#     866     dump_packet(packet)
#
# File c:\Users\olivi\anaconda3\Lib\site-packages\pymysql\connections.py:806, in Connection._write_bytes(self, data)
#     804 self._sock.settimeout(self._write_timeout)
#     805 try:
# --> 806     self._sock.sendall(data)
#     807 except OSError as e:
#     808     self._force_close()
#
# KeyboardInterrupt:
